# %%
import pandas as pd
import numpy as np
import pprint

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_predict, cross_val_score, RandomizedSearchCV, GridSearchCV, StratifiedKFold

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import LinearSVC
import xgboost as xgb
import tensorflow as tf
from tensorflow.keras import layers

# %%
dfRaw = pd.read_csv('/Users/taddbackus/School/fall23/qtw/cs7/final_project(5).csv')
print(dfRaw.head())
# Out:
#          x0        x1         x2        x3  ...       x47       x48        x49  y
# 0 -0.166563 -3.961588   4.621113  2.481908  ... -7.689696  0.151589  -8.040166  0
# 1 -0.149894 -0.585676  27.839856  4.152333  ... -4.896678 -0.320283  16.719974  0
# 2 -0.321707 -1.429819  12.251561  6.586874  ... -7.428573 -2.090804  -7.869421  0
# 3 -0.245594  5.076677 -24.149632  3.637307  ...  5.361375  1.806070  -7.670847  0
# 4 -0.273366  0.306326 -11.352593  1.676758  ... -0.208351 -0.894942  15.724742  1
#
# [5 rows x 51 columns]

# %%
print(dfRaw.describe())
# Out:
#                   x0             x1  ...            x49              y
# count  159974.000000  159975.000000  ...  159968.000000  160000.000000
# mean       -0.001028       0.001358  ...      -0.674224       0.401231
# std         0.371137       6.340632  ...      15.036738       0.490149
# min        -1.592635     -26.278302  ...     -65.791191       0.000000
# 25%        -0.251641      -4.260973  ...     -10.931753       0.000000
# 50%        -0.002047       0.004813  ...      -0.574410       0.000000
# 75%         0.248532       4.284220  ...       9.651072       1.000000
# max         1.600849      27.988178  ...      66.877604       1.000000
#
# [8 rows x 46 columns]

# %%
print(dfRaw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160000 entries, 0 to 159999
# Data columns (total 51 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   x0      159974 non-null  float64
#  1   x1      159975 non-null  float64
#  2   x2      159962 non-null  float64
#  3   x3      159963 non-null  float64
#  4   x4      159974 non-null  float64
#  5   x5      159963 non-null  float64
#  6   x6      159974 non-null  float64
#  7   x7      159973 non-null  float64
#  8   x8      159979 non-null  float64
#  9   x9      159970 non-null  float64
#  10  x10     159957 non-null  float64
#  11  x11     159970 non-null  float64
#  12  x12     159964 non-null  float64
#  13  x13     159969 non-null  float64
#  14  x14     159966 non-null  float64
#  15  x15     159965 non-null  float64
#  16  x16     159974 non-null  float64
#  17  x17     159973 non-null  float64
#  18  x18     159960 non-null  float64
#  19  x19     159965 non-null  float64
#  20  x20     159962 non-null  float64
#  21  x21     159971 non-null  float64
#  22  x22     159973 non-null  float64
#  23  x23     159953 non-null  float64
#  24  x24     159972 non-null  object
#  25  x25     159978 non-null  float64
#  26  x26     159964 non-null  float64
#  27  x27     159970 non-null  float64
#  28  x28     159965 non-null  float64
#  29  x29     159970 non-null  object
#  30  x30     159970 non-null  object
#  31  x31     159961 non-null  float64
#  32  x32     159969 non-null  object
#  33  x33     159959 non-null  float64
#  34  x34     159959 non-null  float64
#  35  x35     159970 non-null  float64
#  36  x36     159973 non-null  float64
#  37  x37     159977 non-null  object
#  38  x38     159969 non-null  float64
#  39  x39     159977 non-null  float64
#  40  x40     159964 non-null  float64
#  41  x41     159960 non-null  float64
#  42  x42     159974 non-null  float64
#  43  x43     159963 non-null  float64
#  44  x44     159960 non-null  float64
#  45  x45     159971 non-null  float64
#  46  x46     159969 non-null  float64
#  47  x47     159963 non-null  float64
#  48  x48     159968 non-null  float64
#  49  x49     159968 non-null  float64
#  50  y       160000 non-null  int64
# dtypes: float64(45), int64(1), object(5)
# memory usage: 62.3+ MB
# None

# %%
df = dfRaw.copy()

# %%
catColumns = df.select_dtypes(include=['object']).columns

for col in catColumns:
    uniqueValues = df[col].unique()
    uniqueCount = len(uniqueValues)
    print(f"Unique values in {col} ({uniqueCount} unique values): \n{uniqueValues}\n\n")
# Out:
# Unique values in x24 (4 unique values):
# ['euorpe' 'asia' 'america' nan]
#
#
# Unique values in x29 (13 unique values):
# ['July' 'Aug' 'Jun' 'May' 'sept.' 'Apr' 'Nov' 'Oct' nan 'Mar' 'Feb' 'Dev'
#  'January']
#
#
# Unique values in x30 (6 unique values):
# ['tuesday' 'wednesday' 'thurday' 'monday' 'friday' nan]
#
#
# Unique values in x32 (13 unique values):
# ['0.0%' '-0.02%' '-0.01%' '0.01%' '-0.03%' '0.02%' '-0.0%' '-0.04%' nan
#  '0.03%' '0.04%' '-0.05%' '0.05%']
#
#
# Unique values in x37 (129199 unique values):
# ['$1313.96' '$1962.78' '$430.47' ... '$1588.65' '$439.21' '$-1229.34']

# %%
def missing_counts(data):
    mCount = 0
    for i in data:
        if data[i].isnull().sum() > 0:
            print(i,':',data[i].isnull().sum(),'missing')
            print('    -',(data[i].isnull().sum() / len(data)) * 100, '%')
            print('=====================')
            mCount += 1
    if mCount == 0:
        print('No Missing Values')

# %%
missing_counts(df)
# Out:
# x0 : 26 missing
#     - 0.01625 %
# =====================
# x1 : 25 missing
#     - 0.015625 %
# =====================
# x2 : 38 missing
#     - 0.02375 %
# =====================
# x3 : 37 missing
#     - 0.023125 %
# =====================
# x4 : 26 missing
#     - 0.01625 %
# =====================
# x5 : 37 missing
#     - 0.023125 %
# =====================
# x6 : 26 missing
#     - 0.01625 %
# =====================
# x7 : 27 missing
#     - 0.016875 %
# =====================
# x8 : 21 missing
#     - 0.013125 %
# =====================
# x9 : 30 missing
#     - 0.01875 %
# =====================
# x10 : 43 missing
#     - 0.026875 %
# =====================
# x11 : 30 missing
#     - 0.01875 %
# =====================
# x12 : 36 missing
#     - 0.0225 %
# =====================
# x13 : 31 missing
#     - 0.019375 %
# =====================
# x14 : 34 missing
#     - 0.021249999999999998 %
# =====================
# x15 : 35 missing
#     - 0.021875000000000002 %
# =====================
# x16 : 26 missing
#     - 0.01625 %
# =====================
# x17 : 27 missing
#     - 0.016875 %
# =====================
# x18 : 40 missing
#     - 0.025 %
# =====================
# x19 : 35 missing
#     - 0.021875000000000002 %
# =====================
# x20 : 38 missing
#     - 0.02375 %
# =====================
# x21 : 29 missing
#     - 0.018125 %
# =====================
# x22 : 27 missing
#     - 0.016875 %
# =====================
# x23 : 47 missing
#     - 0.029375000000000002 %
# =====================
# x24 : 28 missing
#     - 0.017499999999999998 %
# =====================
# x25 : 22 missing
#     - 0.01375 %
# =====================
# x26 : 36 missing
#     - 0.0225 %
# =====================
# x27 : 30 missing
#     - 0.01875 %
# =====================
# x28 : 35 missing
#     - 0.021875000000000002 %
# =====================
# x29 : 30 missing
#     - 0.01875 %
# =====================
# x30 : 30 missing
#     - 0.01875 %
# =====================
# x31 : 39 missing
#     - 0.024374999999999997 %
# =====================
# x32 : 31 missing
#     - 0.019375 %
# =====================
# x33 : 41 missing
#     - 0.025625000000000002 %
# =====================
# x34 : 41 missing
#     - 0.025625000000000002 %
# =====================
# x35 : 30 missing
#     - 0.01875 %
# =====================
# x36 : 27 missing
#     - 0.016875 %
# =====================
# x37 : 23 missing
#     - 0.014374999999999999 %
# =====================
# x38 : 31 missing
#     - 0.019375 %
# =====================
# x39 : 23 missing
#     - 0.014374999999999999 %
# =====================
# x40 : 36 missing
#     - 0.0225 %
# =====================
# x41 : 40 missing
#     - 0.025 %
# =====================
# x42 : 26 missing
#     - 0.01625 %
# =====================
# x43 : 37 missing
#     - 0.023125 %
# =====================
# x44 : 40 missing
#     - 0.025 %
# =====================
# x45 : 29 missing
#     - 0.018125 %
# =====================
# x46 : 31 missing
#     - 0.019375 %
# =====================
# x47 : 37 missing
#     - 0.023125 %
# =====================
# x48 : 32 missing
#     - 0.02 %
# =====================
# x49 : 32 missing
#     - 0.02 %
# =====================

# %% [markdown]
# ### Imputing categorical data

# %%
columnsToEncode = ['x24','x29','x30']
for i in columnsToEncode:
    df[i] = df[i].fillna('unknown')

# %%
missing_counts(df)
# Out:
# x0 : 26 missing
#     - 0.01625 %
# =====================
# x1 : 25 missing
#     - 0.015625 %
# =====================
# x2 : 38 missing
#     - 0.02375 %
# =====================
# x3 : 37 missing
#     - 0.023125 %
# =====================
# x4 : 26 missing
#     - 0.01625 %
# =====================
# x5 : 37 missing
#     - 0.023125 %
# =====================
# x6 : 26 missing
#     - 0.01625 %
# =====================
# x7 : 27 missing
#     - 0.016875 %
# =====================
# x8 : 21 missing
#     - 0.013125 %
# =====================
# x9 : 30 missing
#     - 0.01875 %
# =====================
# x10 : 43 missing
#     - 0.026875 %
# =====================
# x11 : 30 missing
#     - 0.01875 %
# =====================
# x12 : 36 missing
#     - 0.0225 %
# =====================
# x13 : 31 missing
#     - 0.019375 %
# =====================
# x14 : 34 missing
#     - 0.021249999999999998 %
# =====================
# x15 : 35 missing
#     - 0.021875000000000002 %
# =====================
# x16 : 26 missing
#     - 0.01625 %
# =====================
# x17 : 27 missing
#     - 0.016875 %
# =====================
# x18 : 40 missing
#     - 0.025 %
# =====================
# x19 : 35 missing
#     - 0.021875000000000002 %
# =====================
# x20 : 38 missing
#     - 0.02375 %
# =====================
# x21 : 29 missing
#     - 0.018125 %
# =====================
# x22 : 27 missing
#     - 0.016875 %
# =====================
# x23 : 47 missing
#     - 0.029375000000000002 %
# =====================
# x25 : 22 missing
#     - 0.01375 %
# =====================
# x26 : 36 missing
#     - 0.0225 %
# =====================
# x27 : 30 missing
#     - 0.01875 %
# =====================
# x28 : 35 missing
#     - 0.021875000000000002 %
# =====================
# x31 : 39 missing
#     - 0.024374999999999997 %
# =====================
# x32 : 31 missing
#     - 0.019375 %
# =====================
# x33 : 41 missing
#     - 0.025625000000000002 %
# =====================
# x34 : 41 missing
#     - 0.025625000000000002 %
# =====================
# x35 : 30 missing
#     - 0.01875 %
# =====================
# x36 : 27 missing
#     - 0.016875 %
# =====================
# x37 : 23 missing
#     - 0.014374999999999999 %
# =====================
# x38 : 31 missing
#     - 0.019375 %
# =====================
# x39 : 23 missing
#     - 0.014374999999999999 %
# =====================
# x40 : 36 missing
#     - 0.0225 %
# =====================
# x41 : 40 missing
#     - 0.025 %
# =====================
# x42 : 26 missing
#     - 0.01625 %
# =====================
# x43 : 37 missing
#     - 0.023125 %
# =====================
# x44 : 40 missing
#     - 0.025 %
# =====================
# x45 : 29 missing
#     - 0.018125 %
# =====================
# x46 : 31 missing
#     - 0.019375 %
# =====================
# x47 : 37 missing
#     - 0.023125 %
# =====================
# x48 : 32 missing
#     - 0.02 %
# =====================
# x49 : 32 missing
#     - 0.02 %
# =====================

# %%
df['x37'] = df['x37'].str.replace('$','').astype(float)
df['x32'] = df['x32'].str.replace('%','').astype(float)
# Out:
# /var/folders/b6/xllr9jf92s55608_ychrqz700000gn/T/ipykernel_21188/2956702921.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['x37'] = df['x37'].str.replace('$','').astype(float)

# %%
missingData = []
for i in df:
    if df[i].isnull().sum() > 0:
        missingData.append(i)

# %%
for i in missingData:
    df[i].fillna(df[i].median(),inplace=True)
missing_counts(df)
# Out:
# No Missing Values

# %%
df = pd.get_dummies(df,
                    columns=columnsToEncode,
                    prefix=columnsToEncode)

# %% [markdown]
# # Model Setup

# %%
X = df.drop(columns='y')
y = df['y']
print(df.shape)
print(X.shape)
print(y.shape)
# Out:
# (160000, 71)
# (160000, 70)
# (160000,)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# # Score Functions

# %%
valueCounts = df['y'].value_counts()
print(valueCounts)
lowestTotalCost = valueCounts[0] * 40 + valueCounts[1] * 100
print(lowestTotalCost)
# Out:
# 0    95803
# 1    64197
# Name: y, dtype: int64
# 10251820

# %%
def threshold_test(probabilities, th):
    return [1 if prob >= th else 0 for prob in probabilities]
def cost_score(confMatrix):
    return (confMatrix[0,1] * 40 + confMatrix[1][0] * 100)
def find_cost(yTrue, yProb):
    thresholds = np.linspace(0,1,101)
    lowestTh = 1
    lowestCost = lowestTotalCost
    for t in thresholds:
        confMatrix = confusion_matrix(yTrue, threshold_test(yProb,t))
        cost = cost_score(confMatrix)
        if cost < lowestCost:
            lowestCost = cost
            lowestTh = t
            lowestCM = confMatrix
        print('Threshold:',t)
        print('Total Money Lost:',cost)
        print('=====================')
    return lowestCost, lowestTh, lowestCM

# %%
def cross_validation_run(model):
    probs = cross_val_predict(model,
                              X,
                              y,
                              cv=5,
                              n_jobs=-1,
                              method='predict_proba')
    return probs[:,1]

# %% [markdown]
# # Random Forest
# ### Cost: 704,380

# %%
params = {'criterion':['gini','entropy'],
          'max_depth':[5,10,15,20,30,40],
          'min_samples_split':[16,12,10,8,6],
          'min_samples_leaf':[6,5,4,3,2],
          'max_features':[5,10,15,20,30,40],
          'class_weight':[None,'balanced','balanced_subsample']}

rfModel = RandomForestClassifier(n_estimators=10)

rfSearchModel = RandomizedSearchCV(rfModel,
                                   params,
                                   n_iter=20,
                                   cv=5,
                                   n_jobs=-1,
                                   verbose=True)
rfSearchModel.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(n_estimators=10),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'class_weight': [None, 'balanced',
#                                                          'balanced_subsample'],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [5, 10, 15, 20, 30, 40],
#                                         'max_features': [5, 10, 15, 20, 30, 40],
#                                         'min_samples_leaf': [6, 5, 4, 3, 2],
#                                         'min_samples_split': [16, 12, 10, 8,
#                                                               6]},
#                    verbose=True)

# %%
print('RF Search Accuracy:', rfSearchModel.best_score_)
rfBestParams = rfSearchModel.best_params_
print(rfBestParams)
# Out:
# RF Search Accuracy: 0.9202375
# {'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 40, 'max_depth': 20, 'criterion': 'entropy', 'class_weight': 'balanced'}

# %%
rfModel = RandomForestClassifier(n_estimators=50, **rfBestParams)
rfProb = cross_validation_run(rfModel)

# %%
print(find_cost(rfProb))
# Out:
# Threshold: 0.0
# Total Money Lost: 3832120
# =====================
# Threshold: 0.01
# Total Money Lost: 3474100
# =====================
# Threshold: 0.02
# Total Money Lost: 3215600
# =====================
# Threshold: 0.03
# Total Money Lost: 2949860
# =====================
# Threshold: 0.04
# Total Money Lost: 2716540
# =====================
# Threshold: 0.05
# Total Money Lost: 2503160
# =====================
# Threshold: 0.06
# Total Money Lost: 2320700
# =====================
# Threshold: 0.07
# Total Money Lost: 2156340
# =====================
# Threshold: 0.08
# Total Money Lost: 2012400
# =====================
# Threshold: 0.09
# Total Money Lost: 1879440
# =====================
# Threshold: 0.1
# Total Money Lost: 1761320
# =====================
# Threshold: 0.11
# Total Money Lost: 1660440
# =====================
# Threshold: 0.12
# Total Money Lost: 1566480
# =====================
# Threshold: 0.13
# Total Money Lost: 1476900
# =====================
# Threshold: 0.14
# Total Money Lost: 1399540
# =====================
# Threshold: 0.15
# Total Money Lost: 1328660
# =====================
# Threshold: 0.16
# Total Money Lost: 1267240
# =====================
# Threshold: 0.17
# Total Money Lost: 1206780
# =====================
# Threshold: 0.18
# Total Money Lost: 1153160
# =====================
# Threshold: 0.19
# Total Money Lost: 1104260
# =====================
# Threshold: 0.2
# Total Money Lost: 1059500
# =====================
# Threshold: 0.21
# Total Money Lost: 1015180
# =====================
# Threshold: 0.22
# Total Money Lost: 977580
# =====================
# Threshold: 0.23
# Total Money Lost: 940700
# =====================
# Threshold: 0.24
# Total Money Lost: 907100
# =====================
# Threshold: 0.25
# Total Money Lost: 876940
# =====================
# Threshold: 0.26
# Total Money Lost: 849980
# =====================
# Threshold: 0.27
# Total Money Lost: 823700
# =====================
# Threshold: 0.28
# Total Money Lost: 801760
# =====================
# Threshold: 0.29
# Total Money Lost: 783200
# =====================
# Threshold: 0.3
# Total Money Lost: 767640
# =====================
# Threshold: 0.31
# Total Money Lost: 755260
# =====================
# Threshold: 0.32
# Total Money Lost: 739820
# =====================
# Threshold: 0.33
# Total Money Lost: 729220
# =====================
# Threshold: 0.34
# Total Money Lost: 722620
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 715380
# =====================
# Threshold: 0.36
# Total Money Lost: 709760
# =====================
# Threshold: 0.37
# Total Money Lost: 709500
# =====================
# Threshold: 0.38
# Total Money Lost: 705320
# =====================
# Threshold: 0.39
# Total Money Lost: 705660
# =====================
# Threshold: 0.4
# Total Money Lost: 704380
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 707100
# =====================
# Threshold: 0.42
# Total Money Lost: 713120
# =====================
# Threshold: 0.43
# Total Money Lost: 721840
# =====================
# Threshold: 0.44
# Total Money Lost: 730060
# =====================
# Threshold: 0.45
# Total Money Lost: 740600
# =====================
# Threshold: 0.46
# Total Money Lost: 754420
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 767040
# =====================
# Threshold: 0.48
# Total Money Lost: 781000
# =====================
# Threshold: 0.49
# Total Money Lost: 798460
# =====================
# Threshold: 0.5
# Total Money Lost: 814660
# =====================
# Threshold: 0.51
# Total Money Lost: 833880
# =====================
# Threshold: 0.52
# Total Money Lost: 851680
# =====================
# Threshold: 0.53
# Total Money Lost: 874840
# =====================
# Threshold: 0.54
# Total Money Lost: 898540
# =====================
# Threshold: 0.55
# Total Money Lost: 924120
# =====================
# Threshold: 0.56
# Total Money Lost: 950700
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 978800
# =====================
# Threshold: 0.58
# Total Money Lost: 1010900
# =====================
# Threshold: 0.59
# Total Money Lost: 1046400
# =====================
# Threshold: 0.6
# Total Money Lost: 1077480
# =====================
# Threshold: 0.61
# Total Money Lost: 1113480
# =====================
# Threshold: 0.62
# Total Money Lost: 1154440
# =====================
# Threshold: 0.63
# Total Money Lost: 1195180
# =====================
# Threshold: 0.64
# Total Money Lost: 1242040
# =====================
# Threshold: 0.65
# Total Money Lost: 1290360
# =====================
# Threshold: 0.66
# Total Money Lost: 1335360
# =====================
# Threshold: 0.67
# Total Money Lost: 1388100
# =====================
# Threshold: 0.68
# Total Money Lost: 1442760
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 1501100
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 1558240
# =====================
# Threshold: 0.71
# Total Money Lost: 1619440
# =====================
# Threshold: 0.72
# Total Money Lost: 1684260
# =====================
# Threshold: 0.73
# Total Money Lost: 1750360
# =====================
# Threshold: 0.74
# Total Money Lost: 1820360
# =====================
# Threshold: 0.75
# Total Money Lost: 1893560
# =====================
# Threshold: 0.76
# Total Money Lost: 1976640
# =====================
# Threshold: 0.77
# Total Money Lost: 2060400
# =====================
# Threshold: 0.78
# Total Money Lost: 2143800
# =====================
# Threshold: 0.79
# Total Money Lost: 2233440
# =====================
# Threshold: 0.8
# Total Money Lost: 2330200
# =====================
# Threshold: 0.81
# Total Money Lost: 2430360
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 2536640
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 2646120
# =====================
# Threshold: 0.84
# Total Money Lost: 2760220
# =====================
# Threshold: 0.85
# Total Money Lost: 2873820
# =====================
# Threshold: 0.86
# Total Money Lost: 3001460
# =====================
# Threshold: 0.87
# Total Money Lost: 3144280
# =====================
# Threshold: 0.88
# Total Money Lost: 3290160
# =====================
# Threshold: 0.89
# Total Money Lost: 3441260
# =====================
# Threshold: 0.9
# Total Money Lost: 3606640
# =====================
# Threshold: 0.91
# Total Money Lost: 3780960
# =====================
# Threshold: 0.92
# Total Money Lost: 3975900
# =====================
# Threshold: 0.93
# Total Money Lost: 4183800
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 4407900
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 4645000
# =====================
# Threshold: 0.96
# Total Money Lost: 4910740
# =====================
# Threshold: 0.97
# Total Money Lost: 5206420
# =====================
# Threshold: 0.98
# Total Money Lost: 5520820
# =====================
# Threshold: 0.99
# Total Money Lost: 5872020
# =====================
# Threshold: 1.0
# Total Money Lost: 6187080
# =====================
# (704380, 0.4, array([[87236,  8567],
#        [ 3617, 60580]]))

# %% [markdown]
# # Logistic Regression
# ### Cost: 2,798,840

# %%
logModel = LogisticRegression()

# %%
params = {'penalty':['l1','l2','elasticnet'],
          'C':[0.001,0.01,0.1,1,10,100],
          'l1_ratio':[0,0.01,0.25,0.5,0.75,1],
          'solver':['lbfgs','sag','saga','newton-cholesky'],
          'class_weight':[None,'balanced']}

logSearchModel = RandomizedSearchCV(logModel,
                                 params,
                                 n_iter=20,
                                 cv=5,
                                 n_jobs=-1,
                                 verbose=True)
logSearchModel.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 45 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cholesky supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cholesky supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan 0.7083125         nan        nan        nan 0.7083125
#  0.70811875        nan 0.70818125 0.7081125  0.699      0.708325
#         nan 0.708175   0.70263125        nan        nan 0.70815625
#         nan 0.7025875 ]
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(), n_iter=20, n_jobs=-1,
#                    param_distributions={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                                         'class_weight': [None, 'balanced'],
#                                         'l1_ratio': [0, 0.01, 0.25, 0.5, 0.75,
#                                                      1],
#                                         'penalty': ['l1', 'l2', 'elasticnet'],
#                                         'solver': ['lbfgs', 'sag', 'saga',
#                                                    'newton-cholesky']},
#                    verbose=True)

# %%
print(logSearchModel.best_score_)
logBestParams = logSearchModel.best_params_
print(logBestParams)
# Out:
# 0.7083250000000001
# {'solver': 'newton-cholesky', 'penalty': 'l2', 'l1_ratio': 0.01, 'class_weight': 'balanced', 'C': 0.001}

# %%
logModel = LogisticRegression(**logBestParams)
logProb = cross_validation_run(logModel)
# Out:
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(

# %%
print(find_cost(logProb))
# Out:
# Threshold: 0.0
# Total Money Lost: 3832120
# =====================
# Threshold: 0.01
# Total Money Lost: 3832220
# =====================
# Threshold: 0.02
# Total Money Lost: 3832580
# =====================
# Threshold: 0.03
# Total Money Lost: 3832480
# =====================
# Threshold: 0.04
# Total Money Lost: 3832940
# =====================
# Threshold: 0.05
# Total Money Lost: 3833720
# =====================
# Threshold: 0.06
# Total Money Lost: 3833940
# =====================
# Threshold: 0.07
# Total Money Lost: 3833020
# =====================
# Threshold: 0.08
# Total Money Lost: 3832260
# =====================
# Threshold: 0.09
# Total Money Lost: 3829540
# =====================
# Threshold: 0.1
# Total Money Lost: 3826360
# =====================
# Threshold: 0.11
# Total Money Lost: 3819600
# =====================
# Threshold: 0.12
# Total Money Lost: 3810980
# =====================
# Threshold: 0.13
# Total Money Lost: 3797700
# =====================
# Threshold: 0.14
# Total Money Lost: 3780500
# =====================
# Threshold: 0.15
# Total Money Lost: 3760740
# =====================
# Threshold: 0.16
# Total Money Lost: 3737960
# =====================
# Threshold: 0.17
# Total Money Lost: 3708220
# =====================
# Threshold: 0.18
# Total Money Lost: 3674320
# =====================
# Threshold: 0.19
# Total Money Lost: 3639360
# =====================
# Threshold: 0.2
# Total Money Lost: 3595420
# =====================
# Threshold: 0.21
# Total Money Lost: 3551060
# =====================
# Threshold: 0.22
# Total Money Lost: 3504680
# =====================
# Threshold: 0.23
# Total Money Lost: 3453920
# =====================
# Threshold: 0.24
# Total Money Lost: 3400080
# =====================
# Threshold: 0.25
# Total Money Lost: 3341380
# =====================
# Threshold: 0.26
# Total Money Lost: 3285580
# =====================
# Threshold: 0.27
# Total Money Lost: 3227820
# =====================
# Threshold: 0.28
# Total Money Lost: 3173560
# =====================
# Threshold: 0.29
# Total Money Lost: 3117520
# =====================
# Threshold: 0.3
# Total Money Lost: 3058100
# =====================
# Threshold: 0.31
# Total Money Lost: 3007360
# =====================
# Threshold: 0.32
# Total Money Lost: 2963920
# =====================
# Threshold: 0.33
# Total Money Lost: 2929920
# =====================
# Threshold: 0.34
# Total Money Lost: 2893040
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 2861280
# =====================
# Threshold: 0.36
# Total Money Lost: 2838580
# =====================
# Threshold: 0.37
# Total Money Lost: 2819780
# =====================
# Threshold: 0.38
# Total Money Lost: 2806500
# =====================
# Threshold: 0.39
# Total Money Lost: 2799000
# =====================
# Threshold: 0.4
# Total Money Lost: 2798840
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 2803680
# =====================
# Threshold: 0.42
# Total Money Lost: 2813400
# =====================
# Threshold: 0.43
# Total Money Lost: 2826640
# =====================
# Threshold: 0.44
# Total Money Lost: 2846100
# =====================
# Threshold: 0.45
# Total Money Lost: 2875960
# =====================
# Threshold: 0.46
# Total Money Lost: 2905740
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 2947000
# =====================
# Threshold: 0.48
# Total Money Lost: 2991880
# =====================
# Threshold: 0.49
# Total Money Lost: 3051200
# =====================
# Threshold: 0.5
# Total Money Lost: 3102240
# =====================
# Threshold: 0.51
# Total Money Lost: 3163620
# =====================
# Threshold: 0.52
# Total Money Lost: 3221580
# =====================
# Threshold: 0.53
# Total Money Lost: 3279180
# =====================
# Threshold: 0.54
# Total Money Lost: 3350100
# =====================
# Threshold: 0.55
# Total Money Lost: 3422180
# =====================
# Threshold: 0.56
# Total Money Lost: 3499720
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 3569280
# =====================
# Threshold: 0.58
# Total Money Lost: 3649440
# =====================
# Threshold: 0.59
# Total Money Lost: 3728600
# =====================
# Threshold: 0.6
# Total Money Lost: 3809100
# =====================
# Threshold: 0.61
# Total Money Lost: 3890540
# =====================
# Threshold: 0.62
# Total Money Lost: 3972540
# =====================
# Threshold: 0.63
# Total Money Lost: 4054680
# =====================
# Threshold: 0.64
# Total Money Lost: 4141440
# =====================
# Threshold: 0.65
# Total Money Lost: 4233880
# =====================
# Threshold: 0.66
# Total Money Lost: 4318100
# =====================
# Threshold: 0.67
# Total Money Lost: 4409320
# =====================
# Threshold: 0.68
# Total Money Lost: 4496080
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 4590000
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 4672700
# =====================
# Threshold: 0.71
# Total Money Lost: 4762300
# =====================
# Threshold: 0.72
# Total Money Lost: 4852520
# =====================
# Threshold: 0.73
# Total Money Lost: 4938820
# =====================
# Threshold: 0.74
# Total Money Lost: 5024440
# =====================
# Threshold: 0.75
# Total Money Lost: 5110160
# =====================
# Threshold: 0.76
# Total Money Lost: 5188780
# =====================
# Threshold: 0.77
# Total Money Lost: 5266800
# =====================
# Threshold: 0.78
# Total Money Lost: 5347400
# =====================
# Threshold: 0.79
# Total Money Lost: 5425180
# =====================
# Threshold: 0.8
# Total Money Lost: 5499040
# =====================
# Threshold: 0.81
# Total Money Lost: 5571620
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 5642880
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 5710820
# =====================
# Threshold: 0.84
# Total Money Lost: 5772120
# =====================
# Threshold: 0.85
# Total Money Lost: 5838340
# =====================
# Threshold: 0.86
# Total Money Lost: 5897740
# =====================
# Threshold: 0.87
# Total Money Lost: 5955500
# =====================
# Threshold: 0.88
# Total Money Lost: 6014200
# =====================
# Threshold: 0.89
# Total Money Lost: 6068960
# =====================
# Threshold: 0.9
# Total Money Lost: 6122420
# =====================
# Threshold: 0.91
# Total Money Lost: 6175660
# =====================
# Threshold: 0.92
# Total Money Lost: 6220040
# =====================
# Threshold: 0.93
# Total Money Lost: 6259900
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 6297020
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 6335000
# =====================
# Threshold: 0.96
# Total Money Lost: 6365960
# =====================
# Threshold: 0.97
# Total Money Lost: 6390200
# =====================
# Threshold: 0.98
# Total Money Lost: 6407400
# =====================
# Threshold: 0.99
# Total Money Lost: 6417500
# =====================
# Threshold: 1.0
# Total Money Lost: 6419700
# =====================
# (2798840, 0.4, array([[54577, 41226],
#        [11498, 52699]]))

# %% [markdown]
# # Linear SVC
# ### Cost: 3,795,080

# %%
cValues = {'C':[0.001, 0.01, 0.1, 1, 10, 100]}
svmModel = LinearSVC(dual=True)
svmSearchModel = GridSearchCV(svmModel,
                                cValues,
                                cv=5,
                                n_jobs=-1,
                                verbose=True)
svmSearchModel.fit(X,y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# GridSearchCV(cv=5, estimator=LinearSVC(), n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100]}, verbose=True)

# %%
print(svmSearchModel.best_score_)
svmBestParams = svmSearchModel.best_params_
print(svmBestParams)
# Out:
# 0.7021000000000001
# {'C': 0.01}

# %%
svmModel = LinearSVC(dual=True,**svmBestParams)
svmProb = cross_val_predict(svmModel,
                            X,
                            y,
                            cv=5,
                            n_jobs=-1)
#svmProb = cross_validation_run(svmModel)
# Out:
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
print(find_cost(svmProb))
# Out:
# Threshold: 0.0
# Total Money Lost: 3832120
# =====================
# Threshold: 0.01
# Total Money Lost: 3795080
# =====================
# Threshold: 0.02
# Total Money Lost: 3795080
# =====================
# Threshold: 0.03
# Total Money Lost: 3795080
# =====================
# Threshold: 0.04
# Total Money Lost: 3795080
# =====================
# Threshold: 0.05
# Total Money Lost: 3795080
# =====================
# Threshold: 0.06
# Total Money Lost: 3795080
# =====================
# Threshold: 0.07
# Total Money Lost: 3795080
# =====================
# Threshold: 0.08
# Total Money Lost: 3795080
# =====================
# Threshold: 0.09
# Total Money Lost: 3795080
# =====================
# Threshold: 0.1
# Total Money Lost: 3795080
# =====================
# Threshold: 0.11
# Total Money Lost: 3795080
# =====================
# Threshold: 0.12
# Total Money Lost: 3795080
# =====================
# Threshold: 0.13
# Total Money Lost: 3795080
# =====================
# Threshold: 0.14
# Total Money Lost: 3795080
# =====================
# Threshold: 0.15
# Total Money Lost: 3795080
# =====================
# Threshold: 0.16
# Total Money Lost: 3795080
# =====================
# Threshold: 0.17
# Total Money Lost: 3795080
# =====================
# Threshold: 0.18
# Total Money Lost: 3795080
# =====================
# Threshold: 0.19
# Total Money Lost: 3795080
# =====================
# Threshold: 0.2
# Total Money Lost: 3795080
# =====================
# Threshold: 0.21
# Total Money Lost: 3795080
# =====================
# Threshold: 0.22
# Total Money Lost: 3795080
# =====================
# Threshold: 0.23
# Total Money Lost: 3795080
# =====================
# Threshold: 0.24
# Total Money Lost: 3795080
# =====================
# Threshold: 0.25
# Total Money Lost: 3795080
# =====================
# Threshold: 0.26
# Total Money Lost: 3795080
# =====================
# Threshold: 0.27
# Total Money Lost: 3795080
# =====================
# Threshold: 0.28
# Total Money Lost: 3795080
# =====================
# Threshold: 0.29
# Total Money Lost: 3795080
# =====================
# Threshold: 0.3
# Total Money Lost: 3795080
# =====================
# Threshold: 0.31
# Total Money Lost: 3795080
# =====================
# Threshold: 0.32
# Total Money Lost: 3795080
# =====================
# Threshold: 0.33
# Total Money Lost: 3795080
# =====================
# Threshold: 0.34
# Total Money Lost: 3795080
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 3795080
# =====================
# Threshold: 0.36
# Total Money Lost: 3795080
# =====================
# Threshold: 0.37
# Total Money Lost: 3795080
# =====================
# Threshold: 0.38
# Total Money Lost: 3795080
# =====================
# Threshold: 0.39
# Total Money Lost: 3795080
# =====================
# Threshold: 0.4
# Total Money Lost: 3795080
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 3795080
# =====================
# Threshold: 0.42
# Total Money Lost: 3795080
# =====================
# Threshold: 0.43
# Total Money Lost: 3795080
# =====================
# Threshold: 0.44
# Total Money Lost: 3795080
# =====================
# Threshold: 0.45
# Total Money Lost: 3795080
# =====================
# Threshold: 0.46
# Total Money Lost: 3795080
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 3795080
# =====================
# Threshold: 0.48
# Total Money Lost: 3795080
# =====================
# Threshold: 0.49
# Total Money Lost: 3795080
# =====================
# Threshold: 0.5
# Total Money Lost: 3795080
# =====================
# Threshold: 0.51
# Total Money Lost: 3795080
# =====================
# Threshold: 0.52
# Total Money Lost: 3795080
# =====================
# Threshold: 0.53
# Total Money Lost: 3795080
# =====================
# Threshold: 0.54
# Total Money Lost: 3795080
# =====================
# Threshold: 0.55
# Total Money Lost: 3795080
# =====================
# Threshold: 0.56
# Total Money Lost: 3795080
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 3795080
# =====================
# Threshold: 0.58
# Total Money Lost: 3795080
# =====================
# Threshold: 0.59
# Total Money Lost: 3795080
# =====================
# Threshold: 0.6
# Total Money Lost: 3795080
# =====================
# Threshold: 0.61
# Total Money Lost: 3795080
# =====================
# Threshold: 0.62
# Total Money Lost: 3795080
# =====================
# Threshold: 0.63
# Total Money Lost: 3795080
# =====================
# Threshold: 0.64
# Total Money Lost: 3795080
# =====================
# Threshold: 0.65
# Total Money Lost: 3795080
# =====================
# Threshold: 0.66
# Total Money Lost: 3795080
# =====================
# Threshold: 0.67
# Total Money Lost: 3795080
# =====================
# Threshold: 0.68
# Total Money Lost: 3795080
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 3795080
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 3795080
# =====================
# Threshold: 0.71
# Total Money Lost: 3795080
# =====================
# Threshold: 0.72
# Total Money Lost: 3795080
# =====================
# Threshold: 0.73
# Total Money Lost: 3795080
# =====================
# Threshold: 0.74
# Total Money Lost: 3795080
# =====================
# Threshold: 0.75
# Total Money Lost: 3795080
# =====================
# Threshold: 0.76
# Total Money Lost: 3795080
# =====================
# Threshold: 0.77
# Total Money Lost: 3795080
# =====================
# Threshold: 0.78
# Total Money Lost: 3795080
# =====================
# Threshold: 0.79
# Total Money Lost: 3795080
# =====================
# Threshold: 0.8
# Total Money Lost: 3795080
# =====================
# Threshold: 0.81
# Total Money Lost: 3795080
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 3795080
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 3795080
# =====================
# Threshold: 0.84
# Total Money Lost: 3795080
# =====================
# Threshold: 0.85
# Total Money Lost: 3795080
# =====================
# Threshold: 0.86
# Total Money Lost: 3795080
# =====================
# Threshold: 0.87
# Total Money Lost: 3795080
# =====================
# Threshold: 0.88
# Total Money Lost: 3795080
# =====================
# Threshold: 0.89
# Total Money Lost: 3795080
# =====================
# Threshold: 0.9
# Total Money Lost: 3795080
# =====================
# Threshold: 0.91
# Total Money Lost: 3795080
# =====================
# Threshold: 0.92
# Total Money Lost: 3795080
# =====================
# Threshold: 0.93
# Total Money Lost: 3795080
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 3795080
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 3795080
# =====================
# Threshold: 0.96
# Total Money Lost: 3795080
# =====================
# Threshold: 0.97
# Total Money Lost: 3795080
# =====================
# Threshold: 0.98
# Total Money Lost: 3795080
# =====================
# Threshold: 0.99
# Total Money Lost: 3795080
# =====================
# Threshold: 1.0
# Total Money Lost: 3795080
# =====================
# (3795080, 0.01, array([[79611, 16192],
#        [31474, 32723]]))

# %% [markdown]
# # SGD
# ### Cost: 2,819,680

# %%
sgdModel = SGDClassifier(early_stopping=True)

# %%
params = {'loss':['log_loss'],
          'alpha':[0.0001,0.001,0.01,0.1,1,10,100]
          }
sgdSearch = RandomizedSearchCV(sgdModel,
                               params,
                               cv=5,
                               scoring='accuracy')
sgdSearch.fit(X,y)
# Out:
# /Users/taddbackus/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 7 is smaller than n_iter=10. Running 7 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=SGDClassifier(early_stopping=True),
#                    param_distributions={'alpha': [0.0001, 0.001, 0.01, 0.1, 1,
#                                                   10, 100],
#                                         'loss': ['log_loss']},
#                    scoring='accuracy')

# %%
print(sgdSearch.best_score_)
sgdBestParams = sgdSearch.best_params_
print(sgdBestParams)
# Out:
# 0.7014875
# {'loss': 'log_loss', 'alpha': 0.01}

# %%
sgdModel = SGDClassifier(early_stopping=True, **sgdBestParams)
sgdProb = cross_validation_run(sgdModel)

# %%
print(find_cost(sgdProb))
# Out:
# Threshold: 0.0
# Total Money Lost: 3832120
# =====================
# Threshold: 0.01
# Total Money Lost: 3832420
# =====================
# Threshold: 0.02
# Total Money Lost: 3832640
# =====================
# Threshold: 0.03
# Total Money Lost: 3833940
# =====================
# Threshold: 0.04
# Total Money Lost: 3834820
# =====================
# Threshold: 0.05
# Total Money Lost: 3835440
# =====================
# Threshold: 0.06
# Total Money Lost: 3834640
# =====================
# Threshold: 0.07
# Total Money Lost: 3832640
# =====================
# Threshold: 0.08
# Total Money Lost: 3826160
# =====================
# Threshold: 0.09
# Total Money Lost: 3813160
# =====================
# Threshold: 0.1
# Total Money Lost: 3796320
# =====================
# Threshold: 0.11
# Total Money Lost: 3769760
# =====================
# Threshold: 0.12
# Total Money Lost: 3738860
# =====================
# Threshold: 0.13
# Total Money Lost: 3699340
# =====================
# Threshold: 0.14
# Total Money Lost: 3651960
# =====================
# Threshold: 0.15
# Total Money Lost: 3599920
# =====================
# Threshold: 0.16
# Total Money Lost: 3538880
# =====================
# Threshold: 0.17
# Total Money Lost: 3475980
# =====================
# Threshold: 0.18
# Total Money Lost: 3405020
# =====================
# Threshold: 0.19
# Total Money Lost: 3332820
# =====================
# Threshold: 0.2
# Total Money Lost: 3259680
# =====================
# Threshold: 0.21
# Total Money Lost: 3193480
# =====================
# Threshold: 0.22
# Total Money Lost: 3124020
# =====================
# Threshold: 0.23
# Total Money Lost: 3052560
# =====================
# Threshold: 0.24
# Total Money Lost: 3000260
# =====================
# Threshold: 0.25
# Total Money Lost: 2954480
# =====================
# Threshold: 0.26
# Total Money Lost: 2907180
# =====================
# Threshold: 0.27
# Total Money Lost: 2873720
# =====================
# Threshold: 0.28
# Total Money Lost: 2845160
# =====================
# Threshold: 0.29
# Total Money Lost: 2830900
# =====================
# Threshold: 0.3
# Total Money Lost: 2824420
# =====================
# Threshold: 0.31
# Total Money Lost: 2820320
# =====================
# Threshold: 0.32
# Total Money Lost: 2819680
# =====================
# Threshold: 0.33
# Total Money Lost: 2836460
# =====================
# Threshold: 0.34
# Total Money Lost: 2850720
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 2871980
# =====================
# Threshold: 0.36
# Total Money Lost: 2904740
# =====================
# Threshold: 0.37
# Total Money Lost: 2947580
# =====================
# Threshold: 0.38
# Total Money Lost: 2994420
# =====================
# Threshold: 0.39
# Total Money Lost: 3050560
# =====================
# Threshold: 0.4
# Total Money Lost: 3113020
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 3168000
# =====================
# Threshold: 0.42
# Total Money Lost: 3226300
# =====================
# Threshold: 0.43
# Total Money Lost: 3291140
# =====================
# Threshold: 0.44
# Total Money Lost: 3360200
# =====================
# Threshold: 0.45
# Total Money Lost: 3432160
# =====================
# Threshold: 0.46
# Total Money Lost: 3508060
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 3585340
# =====================
# Threshold: 0.48
# Total Money Lost: 3663960
# =====================
# Threshold: 0.49
# Total Money Lost: 3735920
# =====================
# Threshold: 0.5
# Total Money Lost: 3812700
# =====================
# Threshold: 0.51
# Total Money Lost: 3891360
# =====================
# Threshold: 0.52
# Total Money Lost: 3971140
# =====================
# Threshold: 0.53
# Total Money Lost: 4052440
# =====================
# Threshold: 0.54
# Total Money Lost: 4134860
# =====================
# Threshold: 0.55
# Total Money Lost: 4215900
# =====================
# Threshold: 0.56
# Total Money Lost: 4297480
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 4376440
# =====================
# Threshold: 0.58
# Total Money Lost: 4457680
# =====================
# Threshold: 0.59
# Total Money Lost: 4538060
# =====================
# Threshold: 0.6
# Total Money Lost: 4617820
# =====================
# Threshold: 0.61
# Total Money Lost: 4691480
# =====================
# Threshold: 0.62
# Total Money Lost: 4770500
# =====================
# Threshold: 0.63
# Total Money Lost: 4849600
# =====================
# Threshold: 0.64
# Total Money Lost: 4922960
# =====================
# Threshold: 0.65
# Total Money Lost: 5002280
# =====================
# Threshold: 0.66
# Total Money Lost: 5075280
# =====================
# Threshold: 0.67
# Total Money Lost: 5142360
# =====================
# Threshold: 0.68
# Total Money Lost: 5208160
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 5274100
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 5342860
# =====================
# Threshold: 0.71
# Total Money Lost: 5403340
# =====================
# Threshold: 0.72
# Total Money Lost: 5464880
# =====================
# Threshold: 0.73
# Total Money Lost: 5524440
# =====================
# Threshold: 0.74
# Total Money Lost: 5580260
# =====================
# Threshold: 0.75
# Total Money Lost: 5635660
# =====================
# Threshold: 0.76
# Total Money Lost: 5685500
# =====================
# Threshold: 0.77
# Total Money Lost: 5740680
# =====================
# Threshold: 0.78
# Total Money Lost: 5790140
# =====================
# Threshold: 0.79
# Total Money Lost: 5836140
# =====================
# Threshold: 0.8
# Total Money Lost: 5885460
# =====================
# Threshold: 0.81
# Total Money Lost: 5933660
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 5979060
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 6019880
# =====================
# Threshold: 0.84
# Total Money Lost: 6061620
# =====================
# Threshold: 0.85
# Total Money Lost: 6099860
# =====================
# Threshold: 0.86
# Total Money Lost: 6139740
# =====================
# Threshold: 0.87
# Total Money Lost: 6177340
# =====================
# Threshold: 0.88
# Total Money Lost: 6211640
# =====================
# Threshold: 0.89
# Total Money Lost: 6239660
# =====================
# Threshold: 0.9
# Total Money Lost: 6267320
# =====================
# Threshold: 0.91
# Total Money Lost: 6293980
# =====================
# Threshold: 0.92
# Total Money Lost: 6323020
# =====================
# Threshold: 0.93
# Total Money Lost: 6344700
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 6364200
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 6382600
# =====================
# Threshold: 0.96
# Total Money Lost: 6398000
# =====================
# Threshold: 0.97
# Total Money Lost: 6407800
# =====================
# Threshold: 0.98
# Total Money Lost: 6414600
# =====================
# Threshold: 0.99
# Total Money Lost: 6419000
# =====================
# Threshold: 1.0
# Total Money Lost: 6419700
# =====================
# (2819680, 0.32, array([[56466, 39337],
#        [12462, 51735]]))

# %%
y = np.array(y)

# %%
skf = StratifiedKFold(n_splits=5,shuffle=True)
#skf.get_n_splits(X,y)
cvDict = {}

for i, (trainIDX, testIDX) in enumerate(skf.split(X,y)):
    X_train, X_test = X[trainIDX], X[testIDX]
    y_train, y_test = y[trainIDX], y[testIDX]
    cvDict[f'Split {i}'] = [X_train,y_train,X_test,y_test]
    #cvDict[f'Test {i}'] = [X_test,y_test]

pprint.pprint(cvDict)
# Out:
# {'Split 0': [array([[-0.44605786, -0.62505897,  0.43485253, ...,  2.17340491,
#         -0.01369435, -1.31783158],
#        [-0.40114163, -0.09259046,  2.18432376, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-0.86411733, -0.22573363,  1.00978676, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        ...,
#        [ 2.22714248,  0.75755837,  1.75647722, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-2.15965573,  0.84562115,  0.63243641, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [ 0.91689652,  1.20006241,  0.49115971, ..., -0.46010755,
#         -0.01369435,  0.75882231]]),
#              array([0, 0, 0, ..., 0, 1, 0]),
#              array([[-0.73385659,  0.0481012 , -0.76872425, ...,  2.17340491,
#         -0.01369435, -1.31783158],
#        [-0.6081221 ,  1.79003085,  0.90277881, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-1.15928713, -0.15395949, -0.4718607 , ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        ...,
#        [-0.16446191, -0.46857572, -2.08414096, ..., -0.46010755,
#         -0.01369435, -1.31783158],
#        [ 0.58800223, -0.77587147, -2.11061352, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-0.79686213, -0.0653193 , -0.73548202, ...,  2.17340491,
#         -0.01369435, -1.31783158]]),
#              array([1, 0, 1, ..., 0, 0, 1])],
#  'Split 1': [array([[-0.44605786, -0.62505897,  0.43485253, ...,  2.17340491,
#         -0.01369435, -1.31783158],
#        [-0.40114163, -0.09259046,  2.18432376, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-0.86411733, -0.22573363,  1.00978676, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        ...,
#        [-2.15965573,  0.84562115,  0.63243641, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [ 0.91689652,  1.20006241,  0.49115971, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-0.79686213, -0.0653193 , -0.73548202, ...,  2.17340491,
#         -0.01369435, -1.31783158]]),
#              array([0, 0, 0, ..., 1, 0, 1]),
#              array([[-0.36119915,  1.34434249, -0.42051213, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [ 0.54470069, -1.3990479 ,  0.14903067, ...,  2.17340491,
#         -0.01369435, -1.31783158],
#        [ 0.91689858, -1.29597378, -0.14620299, ...,  2.17340491,
#         -0.01369435, -1.31783158],
#        ...,
#        [ 0.17837838,  1.17337734,  0.95893057, ..., -0.46010755,
#         -0.01369435, -1.31783158],
#        [-0.48195767,  0.12971938, -0.33685901, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-0.84239167,  0.51506971, -1.09834477, ..., -0.46010755,
#         -0.01369435,  0.75882231]]),
#              array([1, 1, 0, ..., 0, 0, 0])],
#  'Split 2': [array([[-0.44605786, -0.62505897,  0.43485253, ...,  2.17340491,
#         -0.01369435, -1.31783158],
#        [-0.40114163, -0.09259046,  2.18432376, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-0.86411733, -0.22573363,  1.00978676, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        ...,
#        [-1.30958886, -0.67374593,  0.11811337, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-2.15965573,  0.84562115,  0.63243641, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-0.79686213, -0.0653193 , -0.73548202, ...,  2.17340491,
#         -0.01369435, -1.31783158]]),
#              array([0, 0, 0, ..., 1, 1, 1]),
#              array([[-0.93786038,  0.52566178, -0.16619238, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-0.06674049, -0.96245418,  0.37888372, ..., -0.46010755,
#         -0.01369435, -1.31783158],
#        [-0.08849738, -0.13914041,  0.21891995, ..., -0.46010755,
#         -0.01369435, -1.31783158],
#        ...,
#        [-0.14907415,  0.72206431, -1.26101284, ..., -0.46010755,
#         -0.01369435, -1.31783158],
#        [ 2.22714248,  0.75755837,  1.75647722, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [ 0.91689652,  1.20006241,  0.49115971, ..., -0.46010755,
#         -0.01369435,  0.75882231]]),
#              array([1, 0, 0, ..., 1, 0, 0])],
#  'Split 3': [array([[-0.73385659,  0.0481012 , -0.76872425, ...,  2.17340491,
#         -0.01369435, -1.31783158],
#        [-0.6081221 ,  1.79003085,  0.90277881, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-1.15928713, -0.15395949, -0.4718607 , ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        ...,
#        [-2.15965573,  0.84562115,  0.63243641, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [ 0.91689652,  1.20006241,  0.49115971, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-0.79686213, -0.0653193 , -0.73548202, ...,  2.17340491,
#         -0.01369435, -1.31783158]]),
#              array([1, 0, 1, ..., 1, 0, 1]),
#              array([[-4.46057859e-01, -6.25058973e-01,  4.34852535e-01, ...,
#          2.17340491e+00, -1.36943478e-02, -1.31783158e+00],
#        [-4.01141634e-01, -9.25904609e-02,  2.18432376e+00, ...,
#         -4.60107545e-01, -1.36943478e-02,  7.58822309e-01],
#        [-8.64117330e-01, -2.25733627e-01,  1.00978676e+00, ...,
#         -4.60107545e-01, -1.36943478e-02,  7.58822309e-01],
#        ...,
#        [-7.59195793e-02, -1.15985509e+00, -4.72061939e-01, ...,
#         -4.60107545e-01, -1.36943478e-02,  7.58822309e-01],
#        [ 1.63921585e-02,  4.25115849e-01, -1.35113587e-03, ...,
#         -4.60107545e-01, -1.36943478e-02, -1.31783158e+00],
#        [-8.58096949e-01,  3.83598035e-01,  1.08441706e+00, ...,
#         -4.60107545e-01, -1.36943478e-02,  7.58822309e-01]]),
#              array([0, 0, 0, ..., 0, 0, 0])],
#  'Split 4': [array([[-0.44605786, -0.62505897,  0.43485253, ...,  2.17340491,
#         -0.01369435, -1.31783158],
#        [-0.40114163, -0.09259046,  2.18432376, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-0.86411733, -0.22573363,  1.00978676, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        ...,
#        [ 2.22714248,  0.75755837,  1.75647722, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [ 0.91689652,  1.20006241,  0.49115971, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-0.79686213, -0.0653193 , -0.73548202, ...,  2.17340491,
#         -0.01369435, -1.31783158]]),
#              array([0, 0, 0, ..., 0, 0, 1]),
#              array([[ 0.07470096, -0.91036729,  0.14504564, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-0.89515233,  0.17937451,  0.94160759, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-1.28868026, -0.17139584,  0.57647711, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        ...,
#        [-0.4723908 , -1.29695456, -1.49903011, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-1.30958886, -0.67374593,  0.11811337, ..., -0.46010755,
#         -0.01369435,  0.75882231],
#        [-2.15965573,  0.84562115,  0.63243641, ..., -0.46010755,
#         -0.01369435,  0.75882231]]),
#              array([0, 1, 0, ..., 1, 1, 1])]}

# %%
for i,j in cvDict.items():
    print(i)
    print(j[0].shape)
    print(j[1].shape)
    print(j[2].shape)
    print(j[3].shape)
# Out:
# Split 0
# (128000, 70)
# (128000,)
# (32000, 70)
# (32000,)
# Split 1
# (128000, 70)
# (128000,)
# (32000, 70)
# (32000,)
# Split 2
# (128000, 70)
# (128000,)
# (32000, 70)
# (32000,)
# Split 3
# (128000, 70)
# (128000,)
# (32000, 70)
# (32000,)
# Split 4
# (128000, 70)
# (128000,)
# (32000, 70)
# (32000,)

# %% [markdown]
# # XG Boost
# ### Cost: 638,500

# %%
num_round = 5000
params = {'objective':'binary:logistic',
          'max_depth':8,
          'eta':0.1,
          'eval_metric':'error'}

# %% [markdown]
# in cv dict
# 0 = xtrain
# 1 = ytrain
# 2 = xtest
# 3 = ytest

# %%
#xgbscores = pd.DataFrame()
xgbCost = []
for i,j in cvDict.items():
    print('====================')
    print(i)
    dTrain = xgb.DMatrix(j[0], label=j[1])
    dTest = xgb.DMatrix(j[2], label=j[3])
    evalList = [(dTest,'test'),(dTrain,'train')]
    
    xgbModel = xgb.train(params=params,
                         dtrain=dTrain,
                         num_boost_round=num_round,
                         verbose_eval=False,
                         early_stopping_rounds=5,
                         evals=evalList)
    xgbProb = xgbModel.predict(dTest)
    #xgbProb[i] = xgbModel.predict(dTest)
    splitCost, splitTH, splitCM = find_cost(j[3],xgbProb)
    xgbCost.append(splitCost)

    print('====================')
# Out:
# ====================
# Split 0
# Threshold: 0.0
# Total Money Lost: 766440
# =====================
# Threshold: 0.01
# Total Money Lost: 269780
# =====================
# Threshold: 0.02
# Total Money Lost: 210300
# =====================
# Threshold: 0.03
# Total Money Lost: 181760
# =====================
# Threshold: 0.04
# Total Money Lost: 165120
# =====================
# Threshold: 0.05
# Total Money Lost: 153520
# =====================
# Threshold: 0.06
# Total Money Lost: 146140
# =====================
# Threshold: 0.07
# Total Money Lost: 139560
# =====================
# Threshold: 0.08
# Total Money Lost: 135500
# =====================
# Threshold: 0.09
# Total Money Lost: 131800
# =====================
# Threshold: 0.1
# Total Money Lost: 128460
# =====================
# Threshold: 0.11
# Total Money Lost: 124500
# =====================
# Threshold: 0.12
# Total Money Lost: 121400
# =====================
# Threshold: 0.13
# Total Money Lost: 119520
# =====================
# Threshold: 0.14
# Total Money Lost: 117080
# =====================
# Threshold: 0.15
# Total Money Lost: 115900
# =====================
# Threshold: 0.16
# Total Money Lost: 114360
# =====================
# Threshold: 0.17
# Total Money Lost: 113300
# =====================
# Threshold: 0.18
# Total Money Lost: 112580
# =====================
# Threshold: 0.19
# Total Money Lost: 112080
# =====================
# Threshold: 0.2
# Total Money Lost: 110960
# =====================
# Threshold: 0.21
# Total Money Lost: 111580
# =====================
# Threshold: 0.22
# Total Money Lost: 111500
# =====================
# Threshold: 0.23
# Total Money Lost: 112440
# =====================
# Threshold: 0.24
# Total Money Lost: 111960
# =====================
# Threshold: 0.25
# Total Money Lost: 111940
# =====================
# Threshold: 0.26
# Total Money Lost: 113000
# =====================
# Threshold: 0.27
# Total Money Lost: 113180
# =====================
# Threshold: 0.28
# Total Money Lost: 113640
# =====================
# Threshold: 0.29
# Total Money Lost: 113960
# =====================
# Threshold: 0.3
# Total Money Lost: 114460
# =====================
# Threshold: 0.31
# Total Money Lost: 115020
# =====================
# Threshold: 0.32
# Total Money Lost: 115200
# =====================
# Threshold: 0.33
# Total Money Lost: 115900
# =====================
# Threshold: 0.34
# Total Money Lost: 117080
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 117960
# =====================
# Threshold: 0.36
# Total Money Lost: 119280
# =====================
# Threshold: 0.37
# Total Money Lost: 120520
# =====================
# Threshold: 0.38
# Total Money Lost: 122340
# =====================
# Threshold: 0.39
# Total Money Lost: 123520
# =====================
# Threshold: 0.4
# Total Money Lost: 125340
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 126180
# =====================
# Threshold: 0.42
# Total Money Lost: 127180
# =====================
# Threshold: 0.43
# Total Money Lost: 127540
# =====================
# Threshold: 0.44
# Total Money Lost: 129480
# =====================
# Threshold: 0.45
# Total Money Lost: 131000
# =====================
# Threshold: 0.46
# Total Money Lost: 132180
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 133140
# =====================
# Threshold: 0.48
# Total Money Lost: 134420
# =====================
# Threshold: 0.49
# Total Money Lost: 134980
# =====================
# Threshold: 0.5
# Total Money Lost: 136100
# =====================
# Threshold: 0.51
# Total Money Lost: 137960
# =====================
# Threshold: 0.52
# Total Money Lost: 140220
# =====================
# Threshold: 0.53
# Total Money Lost: 140820
# =====================
# Threshold: 0.54
# Total Money Lost: 143260
# =====================
# Threshold: 0.55
# Total Money Lost: 144700
# =====================
# Threshold: 0.56
# Total Money Lost: 145680
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 147320
# =====================
# Threshold: 0.58
# Total Money Lost: 148620
# =====================
# Threshold: 0.59
# Total Money Lost: 150080
# =====================
# Threshold: 0.6
# Total Money Lost: 151380
# =====================
# Threshold: 0.61
# Total Money Lost: 153200
# =====================
# Threshold: 0.62
# Total Money Lost: 155060
# =====================
# Threshold: 0.63
# Total Money Lost: 156600
# =====================
# Threshold: 0.64
# Total Money Lost: 158720
# =====================
# Threshold: 0.65
# Total Money Lost: 161060
# =====================
# Threshold: 0.66
# Total Money Lost: 162840
# =====================
# Threshold: 0.67
# Total Money Lost: 165160
# =====================
# Threshold: 0.68
# Total Money Lost: 167740
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 170660
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 172680
# =====================
# Threshold: 0.71
# Total Money Lost: 174700
# =====================
# Threshold: 0.72
# Total Money Lost: 177680
# =====================
# Threshold: 0.73
# Total Money Lost: 180560
# =====================
# Threshold: 0.74
# Total Money Lost: 182200
# =====================
# Threshold: 0.75
# Total Money Lost: 186300
# =====================
# Threshold: 0.76
# Total Money Lost: 189440
# =====================
# Threshold: 0.77
# Total Money Lost: 193220
# =====================
# Threshold: 0.78
# Total Money Lost: 197680
# =====================
# Threshold: 0.79
# Total Money Lost: 201080
# =====================
# Threshold: 0.8
# Total Money Lost: 206580
# =====================
# Threshold: 0.81
# Total Money Lost: 210020
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 214040
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 218440
# =====================
# Threshold: 0.84
# Total Money Lost: 223660
# =====================
# Threshold: 0.85
# Total Money Lost: 230880
# =====================
# Threshold: 0.86
# Total Money Lost: 236760
# =====================
# Threshold: 0.87
# Total Money Lost: 243480
# =====================
# Threshold: 0.88
# Total Money Lost: 252680
# =====================
# Threshold: 0.89
# Total Money Lost: 263360
# =====================
# Threshold: 0.9
# Total Money Lost: 272760
# =====================
# Threshold: 0.91
# Total Money Lost: 283040
# =====================
# Threshold: 0.92
# Total Money Lost: 295160
# =====================
# Threshold: 0.93
# Total Money Lost: 310280
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 329260
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 352520
# =====================
# Threshold: 0.96
# Total Money Lost: 386160
# =====================
# Threshold: 0.97
# Total Money Lost: 425080
# =====================
# Threshold: 0.98
# Total Money Lost: 484620
# =====================
# Threshold: 0.99
# Total Money Lost: 598060
# =====================
# Threshold: 1.0
# Total Money Lost: 1283900
# =====================
# ====================
# ====================
# Split 1
# Threshold: 0.0
# Total Money Lost: 766440
# =====================
# Threshold: 0.01
# Total Money Lost: 270020
# =====================
# Threshold: 0.02
# Total Money Lost: 210880
# =====================
# Threshold: 0.03
# Total Money Lost: 184800
# =====================
# Threshold: 0.04
# Total Money Lost: 167320
# =====================
# Threshold: 0.05
# Total Money Lost: 156080
# =====================
# Threshold: 0.06
# Total Money Lost: 146840
# =====================
# Threshold: 0.07
# Total Money Lost: 140380
# =====================
# Threshold: 0.08
# Total Money Lost: 136000
# =====================
# Threshold: 0.09
# Total Money Lost: 131320
# =====================
# Threshold: 0.1
# Total Money Lost: 128200
# =====================
# Threshold: 0.11
# Total Money Lost: 125820
# =====================
# Threshold: 0.12
# Total Money Lost: 122760
# =====================
# Threshold: 0.13
# Total Money Lost: 119460
# =====================
# Threshold: 0.14
# Total Money Lost: 117240
# =====================
# Threshold: 0.15
# Total Money Lost: 117520
# =====================
# Threshold: 0.16
# Total Money Lost: 116960
# =====================
# Threshold: 0.17
# Total Money Lost: 115800
# =====================
# Threshold: 0.18
# Total Money Lost: 115660
# =====================
# Threshold: 0.19
# Total Money Lost: 114900
# =====================
# Threshold: 0.2
# Total Money Lost: 114880
# =====================
# Threshold: 0.21
# Total Money Lost: 115040
# =====================
# Threshold: 0.22
# Total Money Lost: 114680
# =====================
# Threshold: 0.23
# Total Money Lost: 114080
# =====================
# Threshold: 0.24
# Total Money Lost: 113340
# =====================
# Threshold: 0.25
# Total Money Lost: 113640
# =====================
# Threshold: 0.26
# Total Money Lost: 113960
# =====================
# Threshold: 0.27
# Total Money Lost: 114140
# =====================
# Threshold: 0.28
# Total Money Lost: 115420
# =====================
# Threshold: 0.29
# Total Money Lost: 115860
# =====================
# Threshold: 0.3
# Total Money Lost: 116040
# =====================
# Threshold: 0.31
# Total Money Lost: 116000
# =====================
# Threshold: 0.32
# Total Money Lost: 116540
# =====================
# Threshold: 0.33
# Total Money Lost: 118080
# =====================
# Threshold: 0.34
# Total Money Lost: 117980
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 118840
# =====================
# Threshold: 0.36
# Total Money Lost: 119220
# =====================
# Threshold: 0.37
# Total Money Lost: 120380
# =====================
# Threshold: 0.38
# Total Money Lost: 120440
# =====================
# Threshold: 0.39
# Total Money Lost: 120860
# =====================
# Threshold: 0.4
# Total Money Lost: 122180
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 123160
# =====================
# Threshold: 0.42
# Total Money Lost: 124180
# =====================
# Threshold: 0.43
# Total Money Lost: 124640
# =====================
# Threshold: 0.44
# Total Money Lost: 125140
# =====================
# Threshold: 0.45
# Total Money Lost: 125980
# =====================
# Threshold: 0.46
# Total Money Lost: 126880
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 128100
# =====================
# Threshold: 0.48
# Total Money Lost: 129740
# =====================
# Threshold: 0.49
# Total Money Lost: 131060
# =====================
# Threshold: 0.5
# Total Money Lost: 132020
# =====================
# Threshold: 0.51
# Total Money Lost: 133620
# =====================
# Threshold: 0.52
# Total Money Lost: 135360
# =====================
# Threshold: 0.53
# Total Money Lost: 136540
# =====================
# Threshold: 0.54
# Total Money Lost: 138440
# =====================
# Threshold: 0.55
# Total Money Lost: 140080
# =====================
# Threshold: 0.56
# Total Money Lost: 141840
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 144160
# =====================
# Threshold: 0.58
# Total Money Lost: 145600
# =====================
# Threshold: 0.59
# Total Money Lost: 148660
# =====================
# Threshold: 0.6
# Total Money Lost: 150640
# =====================
# Threshold: 0.61
# Total Money Lost: 152100
# =====================
# Threshold: 0.62
# Total Money Lost: 153700
# =====================
# Threshold: 0.63
# Total Money Lost: 155200
# =====================
# Threshold: 0.64
# Total Money Lost: 157200
# =====================
# Threshold: 0.65
# Total Money Lost: 159400
# =====================
# Threshold: 0.66
# Total Money Lost: 161720
# =====================
# Threshold: 0.67
# Total Money Lost: 163940
# =====================
# Threshold: 0.68
# Total Money Lost: 166820
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 169060
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 172140
# =====================
# Threshold: 0.71
# Total Money Lost: 175080
# =====================
# Threshold: 0.72
# Total Money Lost: 177740
# =====================
# Threshold: 0.73
# Total Money Lost: 180900
# =====================
# Threshold: 0.74
# Total Money Lost: 183560
# =====================
# Threshold: 0.75
# Total Money Lost: 187760
# =====================
# Threshold: 0.76
# Total Money Lost: 191940
# =====================
# Threshold: 0.77
# Total Money Lost: 196260
# =====================
# Threshold: 0.78
# Total Money Lost: 201920
# =====================
# Threshold: 0.79
# Total Money Lost: 206220
# =====================
# Threshold: 0.8
# Total Money Lost: 210260
# =====================
# Threshold: 0.81
# Total Money Lost: 215640
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 221080
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 227200
# =====================
# Threshold: 0.84
# Total Money Lost: 232920
# =====================
# Threshold: 0.85
# Total Money Lost: 238240
# =====================
# Threshold: 0.86
# Total Money Lost: 243340
# =====================
# Threshold: 0.87
# Total Money Lost: 251680
# =====================
# Threshold: 0.88
# Total Money Lost: 261520
# =====================
# Threshold: 0.89
# Total Money Lost: 269940
# =====================
# Threshold: 0.9
# Total Money Lost: 279740
# =====================
# Threshold: 0.91
# Total Money Lost: 291620
# =====================
# Threshold: 0.92
# Total Money Lost: 306500
# =====================
# Threshold: 0.93
# Total Money Lost: 318480
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 333980
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 353360
# =====================
# Threshold: 0.96
# Total Money Lost: 380540
# =====================
# Threshold: 0.97
# Total Money Lost: 423320
# =====================
# Threshold: 0.98
# Total Money Lost: 485260
# =====================
# Threshold: 0.99
# Total Money Lost: 599680
# =====================
# Threshold: 1.0
# Total Money Lost: 1283900
# =====================
# ====================
# ====================
# Split 2
# Threshold: 0.0
# Total Money Lost: 766440
# =====================
# Threshold: 0.01
# Total Money Lost: 256340
# =====================
# Threshold: 0.02
# Total Money Lost: 202640
# =====================
# Threshold: 0.03
# Total Money Lost: 174440
# =====================
# Threshold: 0.04
# Total Money Lost: 160000
# =====================
# Threshold: 0.05
# Total Money Lost: 149480
# =====================
# Threshold: 0.06
# Total Money Lost: 142640
# =====================
# Threshold: 0.07
# Total Money Lost: 135540
# =====================
# Threshold: 0.08
# Total Money Lost: 130840
# =====================
# Threshold: 0.09
# Total Money Lost: 126720
# =====================
# Threshold: 0.1
# Total Money Lost: 123900
# =====================
# Threshold: 0.11
# Total Money Lost: 121020
# =====================
# Threshold: 0.12
# Total Money Lost: 119440
# =====================
# Threshold: 0.13
# Total Money Lost: 118500
# =====================
# Threshold: 0.14
# Total Money Lost: 117500
# =====================
# Threshold: 0.15
# Total Money Lost: 116360
# =====================
# Threshold: 0.16
# Total Money Lost: 115620
# =====================
# Threshold: 0.17
# Total Money Lost: 114060
# =====================
# Threshold: 0.18
# Total Money Lost: 113840
# =====================
# Threshold: 0.19
# Total Money Lost: 112920
# =====================
# Threshold: 0.2
# Total Money Lost: 113040
# =====================
# Threshold: 0.21
# Total Money Lost: 113080
# =====================
# Threshold: 0.22
# Total Money Lost: 112580
# =====================
# Threshold: 0.23
# Total Money Lost: 112080
# =====================
# Threshold: 0.24
# Total Money Lost: 112020
# =====================
# Threshold: 0.25
# Total Money Lost: 112400
# =====================
# Threshold: 0.26
# Total Money Lost: 112540
# =====================
# Threshold: 0.27
# Total Money Lost: 113140
# =====================
# Threshold: 0.28
# Total Money Lost: 113100
# =====================
# Threshold: 0.29
# Total Money Lost: 113840
# =====================
# Threshold: 0.3
# Total Money Lost: 114200
# =====================
# Threshold: 0.31
# Total Money Lost: 114020
# =====================
# Threshold: 0.32
# Total Money Lost: 114860
# =====================
# Threshold: 0.33
# Total Money Lost: 115140
# =====================
# Threshold: 0.34
# Total Money Lost: 115240
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 115880
# =====================
# Threshold: 0.36
# Total Money Lost: 116060
# =====================
# Threshold: 0.37
# Total Money Lost: 116260
# =====================
# Threshold: 0.38
# Total Money Lost: 117120
# =====================
# Threshold: 0.39
# Total Money Lost: 118300
# =====================
# Threshold: 0.4
# Total Money Lost: 119720
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 120760
# =====================
# Threshold: 0.42
# Total Money Lost: 121400
# =====================
# Threshold: 0.43
# Total Money Lost: 122640
# =====================
# Threshold: 0.44
# Total Money Lost: 123860
# =====================
# Threshold: 0.45
# Total Money Lost: 125080
# =====================
# Threshold: 0.46
# Total Money Lost: 125380
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 127160
# =====================
# Threshold: 0.48
# Total Money Lost: 128640
# =====================
# Threshold: 0.49
# Total Money Lost: 129840
# =====================
# Threshold: 0.5
# Total Money Lost: 130700
# =====================
# Threshold: 0.51
# Total Money Lost: 131760
# =====================
# Threshold: 0.52
# Total Money Lost: 132660
# =====================
# Threshold: 0.53
# Total Money Lost: 133920
# =====================
# Threshold: 0.54
# Total Money Lost: 134960
# =====================
# Threshold: 0.55
# Total Money Lost: 136300
# =====================
# Threshold: 0.56
# Total Money Lost: 137240
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 138480
# =====================
# Threshold: 0.58
# Total Money Lost: 139460
# =====================
# Threshold: 0.59
# Total Money Lost: 141320
# =====================
# Threshold: 0.6
# Total Money Lost: 142200
# =====================
# Threshold: 0.61
# Total Money Lost: 144100
# =====================
# Threshold: 0.62
# Total Money Lost: 145480
# =====================
# Threshold: 0.63
# Total Money Lost: 147840
# =====================
# Threshold: 0.64
# Total Money Lost: 149360
# =====================
# Threshold: 0.65
# Total Money Lost: 151020
# =====================
# Threshold: 0.66
# Total Money Lost: 152400
# =====================
# Threshold: 0.67
# Total Money Lost: 153960
# =====================
# Threshold: 0.68
# Total Money Lost: 155960
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 158860
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 160740
# =====================
# Threshold: 0.71
# Total Money Lost: 163380
# =====================
# Threshold: 0.72
# Total Money Lost: 166100
# =====================
# Threshold: 0.73
# Total Money Lost: 169300
# =====================
# Threshold: 0.74
# Total Money Lost: 171000
# =====================
# Threshold: 0.75
# Total Money Lost: 173580
# =====================
# Threshold: 0.76
# Total Money Lost: 177600
# =====================
# Threshold: 0.77
# Total Money Lost: 180580
# =====================
# Threshold: 0.78
# Total Money Lost: 184300
# =====================
# Threshold: 0.79
# Total Money Lost: 188700
# =====================
# Threshold: 0.8
# Total Money Lost: 192020
# =====================
# Threshold: 0.81
# Total Money Lost: 195080
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 199100
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 203160
# =====================
# Threshold: 0.84
# Total Money Lost: 208140
# =====================
# Threshold: 0.85
# Total Money Lost: 213940
# =====================
# Threshold: 0.86
# Total Money Lost: 220960
# =====================
# Threshold: 0.87
# Total Money Lost: 228140
# =====================
# Threshold: 0.88
# Total Money Lost: 236580
# =====================
# Threshold: 0.89
# Total Money Lost: 244780
# =====================
# Threshold: 0.9
# Total Money Lost: 253760
# =====================
# Threshold: 0.91
# Total Money Lost: 264160
# =====================
# Threshold: 0.92
# Total Money Lost: 275260
# =====================
# Threshold: 0.93
# Total Money Lost: 291700
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 308860
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 331860
# =====================
# Threshold: 0.96
# Total Money Lost: 361840
# =====================
# Threshold: 0.97
# Total Money Lost: 401280
# =====================
# Threshold: 0.98
# Total Money Lost: 457960
# =====================
# Threshold: 0.99
# Total Money Lost: 567420
# =====================
# Threshold: 1.0
# Total Money Lost: 1283900
# =====================
# ====================
# ====================
# Split 3
# Threshold: 0.0
# Total Money Lost: 766400
# =====================
# Threshold: 0.01
# Total Money Lost: 247880
# =====================
# Threshold: 0.02
# Total Money Lost: 196820
# =====================
# Threshold: 0.03
# Total Money Lost: 169700
# =====================
# Threshold: 0.04
# Total Money Lost: 153400
# =====================
# Threshold: 0.05
# Total Money Lost: 143460
# =====================
# Threshold: 0.06
# Total Money Lost: 135300
# =====================
# Threshold: 0.07
# Total Money Lost: 129560
# =====================
# Threshold: 0.08
# Total Money Lost: 125440
# =====================
# Threshold: 0.09
# Total Money Lost: 119980
# =====================
# Threshold: 0.1
# Total Money Lost: 116920
# =====================
# Threshold: 0.11
# Total Money Lost: 115080
# =====================
# Threshold: 0.12
# Total Money Lost: 113900
# =====================
# Threshold: 0.13
# Total Money Lost: 112780
# =====================
# Threshold: 0.14
# Total Money Lost: 111240
# =====================
# Threshold: 0.15
# Total Money Lost: 109860
# =====================
# Threshold: 0.16
# Total Money Lost: 108840
# =====================
# Threshold: 0.17
# Total Money Lost: 107800
# =====================
# Threshold: 0.18
# Total Money Lost: 107180
# =====================
# Threshold: 0.19
# Total Money Lost: 106440
# =====================
# Threshold: 0.2
# Total Money Lost: 105860
# =====================
# Threshold: 0.21
# Total Money Lost: 106020
# =====================
# Threshold: 0.22
# Total Money Lost: 106540
# =====================
# Threshold: 0.23
# Total Money Lost: 106440
# =====================
# Threshold: 0.24
# Total Money Lost: 106500
# =====================
# Threshold: 0.25
# Total Money Lost: 106540
# =====================
# Threshold: 0.26
# Total Money Lost: 107600
# =====================
# Threshold: 0.27
# Total Money Lost: 108160
# =====================
# Threshold: 0.28
# Total Money Lost: 108660
# =====================
# Threshold: 0.29
# Total Money Lost: 108020
# =====================
# Threshold: 0.3
# Total Money Lost: 108380
# =====================
# Threshold: 0.31
# Total Money Lost: 108460
# =====================
# Threshold: 0.32
# Total Money Lost: 109260
# =====================
# Threshold: 0.33
# Total Money Lost: 109880
# =====================
# Threshold: 0.34
# Total Money Lost: 110340
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 110680
# =====================
# Threshold: 0.36
# Total Money Lost: 112020
# =====================
# Threshold: 0.37
# Total Money Lost: 112820
# =====================
# Threshold: 0.38
# Total Money Lost: 113020
# =====================
# Threshold: 0.39
# Total Money Lost: 114080
# =====================
# Threshold: 0.4
# Total Money Lost: 114880
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 114960
# =====================
# Threshold: 0.42
# Total Money Lost: 115800
# =====================
# Threshold: 0.43
# Total Money Lost: 116200
# =====================
# Threshold: 0.44
# Total Money Lost: 117460
# =====================
# Threshold: 0.45
# Total Money Lost: 119560
# =====================
# Threshold: 0.46
# Total Money Lost: 120640
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 122180
# =====================
# Threshold: 0.48
# Total Money Lost: 122780
# =====================
# Threshold: 0.49
# Total Money Lost: 124240
# =====================
# Threshold: 0.5
# Total Money Lost: 125200
# =====================
# Threshold: 0.51
# Total Money Lost: 126280
# =====================
# Threshold: 0.52
# Total Money Lost: 128040
# =====================
# Threshold: 0.53
# Total Money Lost: 129100
# =====================
# Threshold: 0.54
# Total Money Lost: 129840
# =====================
# Threshold: 0.55
# Total Money Lost: 131520
# =====================
# Threshold: 0.56
# Total Money Lost: 132760
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 134200
# =====================
# Threshold: 0.58
# Total Money Lost: 136300
# =====================
# Threshold: 0.59
# Total Money Lost: 137420
# =====================
# Threshold: 0.6
# Total Money Lost: 140020
# =====================
# Threshold: 0.61
# Total Money Lost: 142100
# =====================
# Threshold: 0.62
# Total Money Lost: 143700
# =====================
# Threshold: 0.63
# Total Money Lost: 146020
# =====================
# Threshold: 0.64
# Total Money Lost: 148200
# =====================
# Threshold: 0.65
# Total Money Lost: 150200
# =====================
# Threshold: 0.66
# Total Money Lost: 152480
# =====================
# Threshold: 0.67
# Total Money Lost: 155100
# =====================
# Threshold: 0.68
# Total Money Lost: 157520
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 159960
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 162880
# =====================
# Threshold: 0.71
# Total Money Lost: 164180
# =====================
# Threshold: 0.72
# Total Money Lost: 166220
# =====================
# Threshold: 0.73
# Total Money Lost: 168940
# =====================
# Threshold: 0.74
# Total Money Lost: 172020
# =====================
# Threshold: 0.75
# Total Money Lost: 175180
# =====================
# Threshold: 0.76
# Total Money Lost: 178080
# =====================
# Threshold: 0.77
# Total Money Lost: 181400
# =====================
# Threshold: 0.78
# Total Money Lost: 184160
# =====================
# Threshold: 0.79
# Total Money Lost: 188140
# =====================
# Threshold: 0.8
# Total Money Lost: 192640
# =====================
# Threshold: 0.81
# Total Money Lost: 196940
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 200100
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 204420
# =====================
# Threshold: 0.84
# Total Money Lost: 209100
# =====================
# Threshold: 0.85
# Total Money Lost: 215120
# =====================
# Threshold: 0.86
# Total Money Lost: 220580
# =====================
# Threshold: 0.87
# Total Money Lost: 226820
# =====================
# Threshold: 0.88
# Total Money Lost: 232860
# =====================
# Threshold: 0.89
# Total Money Lost: 242440
# =====================
# Threshold: 0.9
# Total Money Lost: 252880
# =====================
# Threshold: 0.91
# Total Money Lost: 264040
# =====================
# Threshold: 0.92
# Total Money Lost: 276720
# =====================
# Threshold: 0.93
# Total Money Lost: 291140
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 307620
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 332100
# =====================
# Threshold: 0.96
# Total Money Lost: 358400
# =====================
# Threshold: 0.97
# Total Money Lost: 397340
# =====================
# Threshold: 0.98
# Total Money Lost: 452880
# =====================
# Threshold: 0.99
# Total Money Lost: 557880
# =====================
# Threshold: 1.0
# Total Money Lost: 1284000
# =====================
# ====================
# ====================
# Split 4
# Threshold: 0.0
# Total Money Lost: 766400
# =====================
# Threshold: 0.01
# Total Money Lost: 265100
# =====================
# Threshold: 0.02
# Total Money Lost: 210180
# =====================
# Threshold: 0.03
# Total Money Lost: 179920
# =====================
# Threshold: 0.04
# Total Money Lost: 163340
# =====================
# Threshold: 0.05
# Total Money Lost: 152600
# =====================
# Threshold: 0.06
# Total Money Lost: 143340
# =====================
# Threshold: 0.07
# Total Money Lost: 136180
# =====================
# Threshold: 0.08
# Total Money Lost: 132160
# =====================
# Threshold: 0.09
# Total Money Lost: 128600
# =====================
# Threshold: 0.1
# Total Money Lost: 126560
# =====================
# Threshold: 0.11
# Total Money Lost: 124640
# =====================
# Threshold: 0.12
# Total Money Lost: 122900
# =====================
# Threshold: 0.13
# Total Money Lost: 121740
# =====================
# Threshold: 0.14
# Total Money Lost: 120840
# =====================
# Threshold: 0.15
# Total Money Lost: 119180
# =====================
# Threshold: 0.16
# Total Money Lost: 118780
# =====================
# Threshold: 0.17
# Total Money Lost: 117860
# =====================
# Threshold: 0.18
# Total Money Lost: 117360
# =====================
# Threshold: 0.19
# Total Money Lost: 116960
# =====================
# Threshold: 0.2
# Total Money Lost: 117340
# =====================
# Threshold: 0.21
# Total Money Lost: 116340
# =====================
# Threshold: 0.22
# Total Money Lost: 116500
# =====================
# Threshold: 0.23
# Total Money Lost: 116220
# =====================
# Threshold: 0.24
# Total Money Lost: 116420
# =====================
# Threshold: 0.25
# Total Money Lost: 115960
# =====================
# Threshold: 0.26
# Total Money Lost: 116720
# =====================
# Threshold: 0.27
# Total Money Lost: 116840
# =====================
# Threshold: 0.28
# Total Money Lost: 116980
# =====================
# Threshold: 0.29
# Total Money Lost: 117420
# =====================
# Threshold: 0.3
# Total Money Lost: 118480
# =====================
# Threshold: 0.31
# Total Money Lost: 119700
# =====================
# Threshold: 0.32
# Total Money Lost: 119940
# =====================
# Threshold: 0.33
# Total Money Lost: 120360
# =====================
# Threshold: 0.34
# Total Money Lost: 120920
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 121380
# =====================
# Threshold: 0.36
# Total Money Lost: 121520
# =====================
# Threshold: 0.37
# Total Money Lost: 122180
# =====================
# Threshold: 0.38
# Total Money Lost: 123580
# =====================
# Threshold: 0.39
# Total Money Lost: 125380
# =====================
# Threshold: 0.4
# Total Money Lost: 125360
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 126300
# =====================
# Threshold: 0.42
# Total Money Lost: 126860
# =====================
# Threshold: 0.43
# Total Money Lost: 127620
# =====================
# Threshold: 0.44
# Total Money Lost: 128800
# =====================
# Threshold: 0.45
# Total Money Lost: 129920
# =====================
# Threshold: 0.46
# Total Money Lost: 131020
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 132500
# =====================
# Threshold: 0.48
# Total Money Lost: 133240
# =====================
# Threshold: 0.49
# Total Money Lost: 133780
# =====================
# Threshold: 0.5
# Total Money Lost: 134840
# =====================
# Threshold: 0.51
# Total Money Lost: 135600
# =====================
# Threshold: 0.52
# Total Money Lost: 137180
# =====================
# Threshold: 0.53
# Total Money Lost: 138240
# =====================
# Threshold: 0.54
# Total Money Lost: 139660
# =====================
# Threshold: 0.55
# Total Money Lost: 140780
# =====================
# Threshold: 0.56
# Total Money Lost: 143300
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 144440
# =====================
# Threshold: 0.58
# Total Money Lost: 145940
# =====================
# Threshold: 0.59
# Total Money Lost: 147540
# =====================
# Threshold: 0.6
# Total Money Lost: 148760
# =====================
# Threshold: 0.61
# Total Money Lost: 151760
# =====================
# Threshold: 0.62
# Total Money Lost: 153620
# =====================
# Threshold: 0.63
# Total Money Lost: 155760
# =====================
# Threshold: 0.64
# Total Money Lost: 157500
# =====================
# Threshold: 0.65
# Total Money Lost: 159440
# =====================
# Threshold: 0.66
# Total Money Lost: 161860
# =====================
# Threshold: 0.67
# Total Money Lost: 163780
# =====================
# Threshold: 0.68
# Total Money Lost: 166000
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 168820
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 171740
# =====================
# Threshold: 0.71
# Total Money Lost: 175240
# =====================
# Threshold: 0.72
# Total Money Lost: 178420
# =====================
# Threshold: 0.73
# Total Money Lost: 181600
# =====================
# Threshold: 0.74
# Total Money Lost: 184720
# =====================
# Threshold: 0.75
# Total Money Lost: 188060
# =====================
# Threshold: 0.76
# Total Money Lost: 190380
# =====================
# Threshold: 0.77
# Total Money Lost: 194120
# =====================
# Threshold: 0.78
# Total Money Lost: 197940
# =====================
# Threshold: 0.79
# Total Money Lost: 201580
# =====================
# Threshold: 0.8
# Total Money Lost: 205580
# =====================
# Threshold: 0.81
# Total Money Lost: 211340
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 216500
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 222940
# =====================
# Threshold: 0.84
# Total Money Lost: 229420
# =====================
# Threshold: 0.85
# Total Money Lost: 235500
# =====================
# Threshold: 0.86
# Total Money Lost: 244500
# =====================
# Threshold: 0.87
# Total Money Lost: 249980
# =====================
# Threshold: 0.88
# Total Money Lost: 258700
# =====================
# Threshold: 0.89
# Total Money Lost: 268740
# =====================
# Threshold: 0.9
# Total Money Lost: 279840
# =====================
# Threshold: 0.91
# Total Money Lost: 289620
# =====================
# Threshold: 0.92
# Total Money Lost: 302340
# =====================
# Threshold: 0.93
# Total Money Lost: 317820
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 336080
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 357640
# =====================
# Threshold: 0.96
# Total Money Lost: 387240
# =====================
# Threshold: 0.97
# Total Money Lost: 425160
# =====================
# Threshold: 0.98
# Total Money Lost: 481460
# =====================
# Threshold: 0.99
# Total Money Lost: 591340
# =====================
# Threshold: 1.0
# Total Money Lost: 1284000
# =====================
# ====================

# %%
print(sum(xgbCost))
# Out:
# 558140

# %% [markdown]
# best xg
# max depth 8
# eta 0.1
# 533880

# %% [markdown]
# # Neural Net
# ### Cost: 290,860

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                            patience=5)
nnModel = tf.keras.Sequential()
nnModel.add(tf.keras.Input(shape=(70,)))
nnModel.add(layers.Dense(128,activation='relu'))
nnModel.add(layers.Dense(128,activation='relu'))
nnModel.add(layers.Dropout(0.3))
nnModel.add(layers.Dense(128,activation='relu'))
nnModel.add(layers.Dense(128,activation='relu'))
nnModel.add(layers.Dropout(0.3))
nnModel.add(layers.Dense(1,activation='sigmoid'))
# Out:
# 2023-12-01 10:06:16.855802: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
nnCost = []
for i,j in cvDict.items():
    print('====================')
    print(i)
    xTrain, xVal, yTrain, yVal = train_test_split(j[0],
                                                  j[1],
                                                  test_size=0.1)
    nnModel.compile(optimizer=tf.keras.optimizers.Adam(),
                    loss='binary_crossentropy',
                    metrics=['accuracy'])
    nnFit = nnModel.fit(xTrain,
                        yTrain,
                        epochs=1000,
                        batch_size=32,
                        callbacks=[callback],
                        validation_data=[xVal,yVal])
    nnProb = nnModel.predict(j[2])
    splitCost, splitTH, splitCM = find_cost(j[3],nnProb)
    nnCost.append(splitCost)
# Out:
# ====================
# Split 0
# Epoch 1/1000
# 3600/3600 [==============================] - 6s 1ms/step - loss: 0.3190 - accuracy: 0.8636 - val_loss: 0.2027 - val_accuracy: 0.9189
# Epoch 2/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.2030 - accuracy: 0.9225 - val_loss: 0.1697 - val_accuracy: 0.9359
# Epoch 3/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1716 - accuracy: 0.9372 - val_loss: 0.1561 - val_accuracy: 0.9432
# Epoch 4/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1558 - accuracy: 0.9445 - val_loss: 0.1414 - val_accuracy: 0.9479
# Epoch 5/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1439 - accuracy: 0.9496 - val_loss: 0.1382 - val_accuracy: 0.9531
# Epoch 6/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1341 - accuracy: 0.9534 - val_loss: 0.1307 - val_accuracy: 0.9522
# Epoch 7/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1276 - accuracy: 0.9564 - val_loss: 0.1236 - val_accuracy: 0.9562
# Epoch 8/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1216 - accuracy: 0.9598 - val_loss: 0.1201 - val_accuracy: 0.9581
# Epoch 9/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1160 - accuracy: 0.9617 - val_loss: 0.1267 - val_accuracy: 0.9559
# Epoch 10/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1128 - accuracy: 0.9626 - val_loss: 0.1136 - val_accuracy: 0.9623
# Epoch 11/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1086 - accuracy: 0.9645 - val_loss: 0.1149 - val_accuracy: 0.9609
# Epoch 12/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1054 - accuracy: 0.9660 - val_loss: 0.1062 - val_accuracy: 0.9646
# Epoch 13/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1025 - accuracy: 0.9667 - val_loss: 0.1166 - val_accuracy: 0.9610
# Epoch 14/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0996 - accuracy: 0.9679 - val_loss: 0.1077 - val_accuracy: 0.9636
# Epoch 15/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0963 - accuracy: 0.9695 - val_loss: 0.1119 - val_accuracy: 0.9624
# Epoch 16/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0957 - accuracy: 0.9695 - val_loss: 0.1093 - val_accuracy: 0.9653
# Epoch 17/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0938 - accuracy: 0.9700 - val_loss: 0.1122 - val_accuracy: 0.9649
# 1000/1000 [==============================] - 1s 576us/step
# Threshold: 0.0
# Total Money Lost: 766440
# =====================
# Threshold: 0.01
# Total Money Lost: 359480
# =====================
# Threshold: 0.02
# Total Money Lost: 246460
# =====================
# Threshold: 0.03
# Total Money Lost: 186300
# =====================
# Threshold: 0.04
# Total Money Lost: 152800
# =====================
# Threshold: 0.05
# Total Money Lost: 130220
# =====================
# Threshold: 0.06
# Total Money Lost: 115680
# =====================
# Threshold: 0.07
# Total Money Lost: 105260
# =====================
# Threshold: 0.08
# Total Money Lost: 99540
# =====================
# Threshold: 0.09
# Total Money Lost: 94860
# =====================
# Threshold: 0.1
# Total Money Lost: 92040
# =====================
# Threshold: 0.11
# Total Money Lost: 89820
# =====================
# Threshold: 0.12
# Total Money Lost: 86500
# =====================
# Threshold: 0.13
# Total Money Lost: 85280
# =====================
# Threshold: 0.14
# Total Money Lost: 83600
# =====================
# Threshold: 0.15
# Total Money Lost: 83060
# =====================
# Threshold: 0.16
# Total Money Lost: 82500
# =====================
# Threshold: 0.17
# Total Money Lost: 81320
# =====================
# Threshold: 0.18
# Total Money Lost: 80920
# =====================
# Threshold: 0.19
# Total Money Lost: 80200
# =====================
# Threshold: 0.2
# Total Money Lost: 80060
# =====================
# Threshold: 0.21
# Total Money Lost: 80060
# =====================
# Threshold: 0.22
# Total Money Lost: 79180
# =====================
# Threshold: 0.23
# Total Money Lost: 79140
# =====================
# Threshold: 0.24
# Total Money Lost: 79400
# =====================
# Threshold: 0.25
# Total Money Lost: 80320
# =====================
# Threshold: 0.26
# Total Money Lost: 80040
# =====================
# Threshold: 0.27
# Total Money Lost: 79880
# =====================
# Threshold: 0.28
# Total Money Lost: 79580
# =====================
# Threshold: 0.29
# Total Money Lost: 79700
# =====================
# Threshold: 0.3
# Total Money Lost: 79620
# =====================
# Threshold: 0.31
# Total Money Lost: 79220
# =====================
# Threshold: 0.32
# Total Money Lost: 79640
# =====================
# Threshold: 0.33
# Total Money Lost: 79900
# =====================
# Threshold: 0.34
# Total Money Lost: 79880
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 79960
# =====================
# Threshold: 0.36
# Total Money Lost: 80080
# =====================
# Threshold: 0.37
# Total Money Lost: 80120
# =====================
# Threshold: 0.38
# Total Money Lost: 80160
# =====================
# Threshold: 0.39
# Total Money Lost: 80240
# =====================
# Threshold: 0.4
# Total Money Lost: 80660
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 82120
# =====================
# Threshold: 0.42
# Total Money Lost: 82720
# =====================
# Threshold: 0.43
# Total Money Lost: 82540
# =====================
# Threshold: 0.44
# Total Money Lost: 83440
# =====================
# Threshold: 0.45
# Total Money Lost: 83920
# =====================
# Threshold: 0.46
# Total Money Lost: 83880
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 84020
# =====================
# Threshold: 0.48
# Total Money Lost: 84820
# =====================
# Threshold: 0.49
# Total Money Lost: 85180
# =====================
# Threshold: 0.5
# Total Money Lost: 85840
# =====================
# Threshold: 0.51
# Total Money Lost: 87020
# =====================
# Threshold: 0.52
# Total Money Lost: 87600
# =====================
# Threshold: 0.53
# Total Money Lost: 88100
# =====================
# Threshold: 0.54
# Total Money Lost: 88700
# =====================
# Threshold: 0.55
# Total Money Lost: 88900
# =====================
# Threshold: 0.56
# Total Money Lost: 89260
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 90540
# =====================
# Threshold: 0.58
# Total Money Lost: 90600
# =====================
# Threshold: 0.59
# Total Money Lost: 91120
# =====================
# Threshold: 0.6
# Total Money Lost: 91840
# =====================
# Threshold: 0.61
# Total Money Lost: 93380
# =====================
# Threshold: 0.62
# Total Money Lost: 94940
# =====================
# Threshold: 0.63
# Total Money Lost: 96060
# =====================
# Threshold: 0.64
# Total Money Lost: 97180
# =====================
# Threshold: 0.65
# Total Money Lost: 98040
# =====================
# Threshold: 0.66
# Total Money Lost: 99460
# =====================
# Threshold: 0.67
# Total Money Lost: 100500
# =====================
# Threshold: 0.68
# Total Money Lost: 103220
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 104760
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 106360
# =====================
# Threshold: 0.71
# Total Money Lost: 107640
# =====================
# Threshold: 0.72
# Total Money Lost: 109800
# =====================
# Threshold: 0.73
# Total Money Lost: 111400
# =====================
# Threshold: 0.74
# Total Money Lost: 113820
# =====================
# Threshold: 0.75
# Total Money Lost: 116420
# =====================
# Threshold: 0.76
# Total Money Lost: 119120
# =====================
# Threshold: 0.77
# Total Money Lost: 122000
# =====================
# Threshold: 0.78
# Total Money Lost: 124100
# =====================
# Threshold: 0.79
# Total Money Lost: 127400
# =====================
# Threshold: 0.8
# Total Money Lost: 130380
# =====================
# Threshold: 0.81
# Total Money Lost: 133760
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 138560
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 143640
# =====================
# Threshold: 0.84
# Total Money Lost: 149840
# =====================
# Threshold: 0.85
# Total Money Lost: 156280
# =====================
# Threshold: 0.86
# Total Money Lost: 163480
# =====================
# Threshold: 0.87
# Total Money Lost: 171340
# =====================
# Threshold: 0.88
# Total Money Lost: 180640
# =====================
# Threshold: 0.89
# Total Money Lost: 192940
# =====================
# Threshold: 0.9
# Total Money Lost: 206820
# =====================
# Threshold: 0.91
# Total Money Lost: 222720
# =====================
# Threshold: 0.92
# Total Money Lost: 243000
# =====================
# Threshold: 0.93
# Total Money Lost: 270100
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 303140
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 349600
# =====================
# Threshold: 0.96
# Total Money Lost: 411020
# =====================
# Threshold: 0.97
# Total Money Lost: 484520
# =====================
# Threshold: 0.98
# Total Money Lost: 595800
# =====================
# Threshold: 0.99
# Total Money Lost: 775300
# =====================
# Threshold: 1.0
# Total Money Lost: 1283400
# =====================
# ====================
# Split 1
# Epoch 1/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1030 - accuracy: 0.9680 - val_loss: 0.0942 - val_accuracy: 0.9730
# Epoch 2/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0977 - accuracy: 0.9689 - val_loss: 0.0904 - val_accuracy: 0.9736
# Epoch 3/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0932 - accuracy: 0.9714 - val_loss: 0.0973 - val_accuracy: 0.9708
# Epoch 4/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0907 - accuracy: 0.9715 - val_loss: 0.0931 - val_accuracy: 0.9727
# Epoch 5/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0894 - accuracy: 0.9727 - val_loss: 0.0965 - val_accuracy: 0.9700
# Epoch 6/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0861 - accuracy: 0.9734 - val_loss: 0.0955 - val_accuracy: 0.9707
# Epoch 7/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0867 - accuracy: 0.9738 - val_loss: 0.0971 - val_accuracy: 0.9699
# 1000/1000 [==============================] - 1s 577us/step
# Threshold: 0.0
# Total Money Lost: 766440
# =====================
# Threshold: 0.01
# Total Money Lost: 176780
# =====================
# Threshold: 0.02
# Total Money Lost: 111160
# =====================
# Threshold: 0.03
# Total Money Lost: 91380
# =====================
# Threshold: 0.04
# Total Money Lost: 82060
# =====================
# Threshold: 0.05
# Total Money Lost: 76740
# =====================
# Threshold: 0.06
# Total Money Lost: 73760
# =====================
# Threshold: 0.07
# Total Money Lost: 71240
# =====================
# Threshold: 0.08
# Total Money Lost: 68760
# =====================
# Threshold: 0.09
# Total Money Lost: 68000
# =====================
# Threshold: 0.1
# Total Money Lost: 66680
# =====================
# Threshold: 0.11
# Total Money Lost: 65960
# =====================
# Threshold: 0.12
# Total Money Lost: 64920
# =====================
# Threshold: 0.13
# Total Money Lost: 64720
# =====================
# Threshold: 0.14
# Total Money Lost: 64700
# =====================
# Threshold: 0.15
# Total Money Lost: 64280
# =====================
# Threshold: 0.16
# Total Money Lost: 63960
# =====================
# Threshold: 0.17
# Total Money Lost: 64100
# =====================
# Threshold: 0.18
# Total Money Lost: 64300
# =====================
# Threshold: 0.19
# Total Money Lost: 64540
# =====================
# Threshold: 0.2
# Total Money Lost: 64540
# =====================
# Threshold: 0.21
# Total Money Lost: 64600
# =====================
# Threshold: 0.22
# Total Money Lost: 64240
# =====================
# Threshold: 0.23
# Total Money Lost: 64440
# =====================
# Threshold: 0.24
# Total Money Lost: 64380
# =====================
# Threshold: 0.25
# Total Money Lost: 64240
# =====================
# Threshold: 0.26
# Total Money Lost: 64380
# =====================
# Threshold: 0.27
# Total Money Lost: 64400
# =====================
# Threshold: 0.28
# Total Money Lost: 65000
# =====================
# Threshold: 0.29
# Total Money Lost: 64920
# =====================
# Threshold: 0.3
# Total Money Lost: 65240
# =====================
# Threshold: 0.31
# Total Money Lost: 65300
# =====================
# Threshold: 0.32
# Total Money Lost: 65240
# =====================
# Threshold: 0.33
# Total Money Lost: 65280
# =====================
# Threshold: 0.34
# Total Money Lost: 65180
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 65340
# =====================
# Threshold: 0.36
# Total Money Lost: 65640
# =====================
# Threshold: 0.37
# Total Money Lost: 65620
# =====================
# Threshold: 0.38
# Total Money Lost: 66440
# =====================
# Threshold: 0.39
# Total Money Lost: 66840
# =====================
# Threshold: 0.4
# Total Money Lost: 67020
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 67520
# =====================
# Threshold: 0.42
# Total Money Lost: 67640
# =====================
# Threshold: 0.43
# Total Money Lost: 68080
# =====================
# Threshold: 0.44
# Total Money Lost: 68860
# =====================
# Threshold: 0.45
# Total Money Lost: 69340
# =====================
# Threshold: 0.46
# Total Money Lost: 69660
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 70040
# =====================
# Threshold: 0.48
# Total Money Lost: 70960
# =====================
# Threshold: 0.49
# Total Money Lost: 71620
# =====================
# Threshold: 0.5
# Total Money Lost: 72440
# =====================
# Threshold: 0.51
# Total Money Lost: 72980
# =====================
# Threshold: 0.52
# Total Money Lost: 73180
# =====================
# Threshold: 0.53
# Total Money Lost: 73780
# =====================
# Threshold: 0.54
# Total Money Lost: 74720
# =====================
# Threshold: 0.55
# Total Money Lost: 74840
# =====================
# Threshold: 0.56
# Total Money Lost: 75020
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 75460
# =====================
# Threshold: 0.58
# Total Money Lost: 76280
# =====================
# Threshold: 0.59
# Total Money Lost: 77720
# =====================
# Threshold: 0.6
# Total Money Lost: 78640
# =====================
# Threshold: 0.61
# Total Money Lost: 80180
# =====================
# Threshold: 0.62
# Total Money Lost: 81360
# =====================
# Threshold: 0.63
# Total Money Lost: 81780
# =====================
# Threshold: 0.64
# Total Money Lost: 82600
# =====================
# Threshold: 0.65
# Total Money Lost: 83240
# =====================
# Threshold: 0.66
# Total Money Lost: 84160
# =====================
# Threshold: 0.67
# Total Money Lost: 85080
# =====================
# Threshold: 0.68
# Total Money Lost: 87220
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 88280
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 90240
# =====================
# Threshold: 0.71
# Total Money Lost: 92080
# =====================
# Threshold: 0.72
# Total Money Lost: 93580
# =====================
# Threshold: 0.73
# Total Money Lost: 94560
# =====================
# Threshold: 0.74
# Total Money Lost: 96580
# =====================
# Threshold: 0.75
# Total Money Lost: 98840
# =====================
# Threshold: 0.76
# Total Money Lost: 100860
# =====================
# Threshold: 0.77
# Total Money Lost: 103220
# =====================
# Threshold: 0.78
# Total Money Lost: 105580
# =====================
# Threshold: 0.79
# Total Money Lost: 107780
# =====================
# Threshold: 0.8
# Total Money Lost: 109900
# =====================
# Threshold: 0.81
# Total Money Lost: 112180
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 115160
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 119400
# =====================
# Threshold: 0.84
# Total Money Lost: 123680
# =====================
# Threshold: 0.85
# Total Money Lost: 128160
# =====================
# Threshold: 0.86
# Total Money Lost: 133480
# =====================
# Threshold: 0.87
# Total Money Lost: 139320
# =====================
# Threshold: 0.88
# Total Money Lost: 145160
# =====================
# Threshold: 0.89
# Total Money Lost: 152640
# =====================
# Threshold: 0.9
# Total Money Lost: 161500
# =====================
# Threshold: 0.91
# Total Money Lost: 171260
# =====================
# Threshold: 0.92
# Total Money Lost: 185260
# =====================
# Threshold: 0.93
# Total Money Lost: 201700
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 223140
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 255240
# =====================
# Threshold: 0.96
# Total Money Lost: 294860
# =====================
# Threshold: 0.97
# Total Money Lost: 354180
# =====================
# Threshold: 0.98
# Total Money Lost: 446540
# =====================
# Threshold: 0.99
# Total Money Lost: 620620
# =====================
# Threshold: 1.0
# Total Money Lost: 1283900
# =====================
# ====================
# Split 2
# Epoch 1/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0952 - accuracy: 0.9711 - val_loss: 0.0869 - val_accuracy: 0.9757
# Epoch 2/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0907 - accuracy: 0.9721 - val_loss: 0.0839 - val_accuracy: 0.9749
# Epoch 3/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0887 - accuracy: 0.9732 - val_loss: 0.0825 - val_accuracy: 0.9747
# Epoch 4/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0857 - accuracy: 0.9740 - val_loss: 0.0882 - val_accuracy: 0.9717
# Epoch 5/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0832 - accuracy: 0.9748 - val_loss: 0.0851 - val_accuracy: 0.9751
# Epoch 6/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0810 - accuracy: 0.9754 - val_loss: 0.0903 - val_accuracy: 0.9736
# Epoch 7/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0795 - accuracy: 0.9764 - val_loss: 0.0894 - val_accuracy: 0.9716
# Epoch 8/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0803 - accuracy: 0.9760 - val_loss: 0.0917 - val_accuracy: 0.9716
# 1000/1000 [==============================] - 1s 573us/step
# Threshold: 0.0
# Total Money Lost: 766440
# =====================
# Threshold: 0.01
# Total Money Lost: 174260
# =====================
# Threshold: 0.02
# Total Money Lost: 104200
# =====================
# Threshold: 0.03
# Total Money Lost: 81960
# =====================
# Threshold: 0.04
# Total Money Lost: 72480
# =====================
# Threshold: 0.05
# Total Money Lost: 66040
# =====================
# Threshold: 0.06
# Total Money Lost: 62500
# =====================
# Threshold: 0.07
# Total Money Lost: 59560
# =====================
# Threshold: 0.08
# Total Money Lost: 58960
# =====================
# Threshold: 0.09
# Total Money Lost: 57540
# =====================
# Threshold: 0.1
# Total Money Lost: 56040
# =====================
# Threshold: 0.11
# Total Money Lost: 55340
# =====================
# Threshold: 0.12
# Total Money Lost: 55020
# =====================
# Threshold: 0.13
# Total Money Lost: 54460
# =====================
# Threshold: 0.14
# Total Money Lost: 54300
# =====================
# Threshold: 0.15
# Total Money Lost: 54100
# =====================
# Threshold: 0.16
# Total Money Lost: 53740
# =====================
# Threshold: 0.17
# Total Money Lost: 53960
# =====================
# Threshold: 0.18
# Total Money Lost: 54480
# =====================
# Threshold: 0.19
# Total Money Lost: 54860
# =====================
# Threshold: 0.2
# Total Money Lost: 55040
# =====================
# Threshold: 0.21
# Total Money Lost: 55760
# =====================
# Threshold: 0.22
# Total Money Lost: 56620
# =====================
# Threshold: 0.23
# Total Money Lost: 56580
# =====================
# Threshold: 0.24
# Total Money Lost: 57300
# =====================
# Threshold: 0.25
# Total Money Lost: 57560
# =====================
# Threshold: 0.26
# Total Money Lost: 57980
# =====================
# Threshold: 0.27
# Total Money Lost: 58220
# =====================
# Threshold: 0.28
# Total Money Lost: 58920
# =====================
# Threshold: 0.29
# Total Money Lost: 58900
# =====================
# Threshold: 0.3
# Total Money Lost: 59220
# =====================
# Threshold: 0.31
# Total Money Lost: 59920
# =====================
# Threshold: 0.32
# Total Money Lost: 60260
# =====================
# Threshold: 0.33
# Total Money Lost: 60960
# =====================
# Threshold: 0.34
# Total Money Lost: 61420
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 61840
# =====================
# Threshold: 0.36
# Total Money Lost: 62420
# =====================
# Threshold: 0.37
# Total Money Lost: 62620
# =====================
# Threshold: 0.38
# Total Money Lost: 63020
# =====================
# Threshold: 0.39
# Total Money Lost: 63180
# =====================
# Threshold: 0.4
# Total Money Lost: 64120
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 64740
# =====================
# Threshold: 0.42
# Total Money Lost: 65540
# =====================
# Threshold: 0.43
# Total Money Lost: 66180
# =====================
# Threshold: 0.44
# Total Money Lost: 66440
# =====================
# Threshold: 0.45
# Total Money Lost: 66720
# =====================
# Threshold: 0.46
# Total Money Lost: 67700
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 69000
# =====================
# Threshold: 0.48
# Total Money Lost: 70220
# =====================
# Threshold: 0.49
# Total Money Lost: 70540
# =====================
# Threshold: 0.5
# Total Money Lost: 71540
# =====================
# Threshold: 0.51
# Total Money Lost: 71640
# =====================
# Threshold: 0.52
# Total Money Lost: 72680
# =====================
# Threshold: 0.53
# Total Money Lost: 73300
# =====================
# Threshold: 0.54
# Total Money Lost: 73760
# =====================
# Threshold: 0.55
# Total Money Lost: 74200
# =====================
# Threshold: 0.56
# Total Money Lost: 74760
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 75600
# =====================
# Threshold: 0.58
# Total Money Lost: 76520
# =====================
# Threshold: 0.59
# Total Money Lost: 76960
# =====================
# Threshold: 0.6
# Total Money Lost: 77000
# =====================
# Threshold: 0.61
# Total Money Lost: 77600
# =====================
# Threshold: 0.62
# Total Money Lost: 78700
# =====================
# Threshold: 0.63
# Total Money Lost: 79400
# =====================
# Threshold: 0.64
# Total Money Lost: 80200
# =====================
# Threshold: 0.65
# Total Money Lost: 80900
# =====================
# Threshold: 0.66
# Total Money Lost: 82000
# =====================
# Threshold: 0.67
# Total Money Lost: 83200
# =====================
# Threshold: 0.68
# Total Money Lost: 85420
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 87060
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 88700
# =====================
# Threshold: 0.71
# Total Money Lost: 90000
# =====================
# Threshold: 0.72
# Total Money Lost: 91120
# =====================
# Threshold: 0.73
# Total Money Lost: 92560
# =====================
# Threshold: 0.74
# Total Money Lost: 94960
# =====================
# Threshold: 0.75
# Total Money Lost: 97080
# =====================
# Threshold: 0.76
# Total Money Lost: 98540
# =====================
# Threshold: 0.77
# Total Money Lost: 100300
# =====================
# Threshold: 0.78
# Total Money Lost: 102500
# =====================
# Threshold: 0.79
# Total Money Lost: 104940
# =====================
# Threshold: 0.8
# Total Money Lost: 107920
# =====================
# Threshold: 0.81
# Total Money Lost: 111100
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 114120
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 117740
# =====================
# Threshold: 0.84
# Total Money Lost: 121580
# =====================
# Threshold: 0.85
# Total Money Lost: 124960
# =====================
# Threshold: 0.86
# Total Money Lost: 130180
# =====================
# Threshold: 0.87
# Total Money Lost: 135640
# =====================
# Threshold: 0.88
# Total Money Lost: 141180
# =====================
# Threshold: 0.89
# Total Money Lost: 147960
# =====================
# Threshold: 0.9
# Total Money Lost: 155560
# =====================
# Threshold: 0.91
# Total Money Lost: 165680
# =====================
# Threshold: 0.92
# Total Money Lost: 177620
# =====================
# Threshold: 0.93
# Total Money Lost: 189560
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 208040
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 235720
# =====================
# Threshold: 0.96
# Total Money Lost: 275540
# =====================
# Threshold: 0.97
# Total Money Lost: 335320
# =====================
# Threshold: 0.98
# Total Money Lost: 437060
# =====================
# Threshold: 0.99
# Total Money Lost: 620880
# =====================
# Threshold: 1.0
# Total Money Lost: 1283600
# =====================
# ====================
# Split 3
# Epoch 1/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0895 - accuracy: 0.9732 - val_loss: 0.0702 - val_accuracy: 0.9784
# Epoch 2/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0836 - accuracy: 0.9748 - val_loss: 0.0767 - val_accuracy: 0.9762
# Epoch 3/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0820 - accuracy: 0.9758 - val_loss: 0.0783 - val_accuracy: 0.9749
# Epoch 4/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0798 - accuracy: 0.9762 - val_loss: 0.0839 - val_accuracy: 0.9735
# Epoch 5/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0785 - accuracy: 0.9767 - val_loss: 0.0788 - val_accuracy: 0.9742
# Epoch 6/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0765 - accuracy: 0.9774 - val_loss: 0.0849 - val_accuracy: 0.9722
# 1000/1000 [==============================] - 1s 592us/step
# Threshold: 0.0
# Total Money Lost: 766400
# =====================
# Threshold: 0.01
# Total Money Lost: 351200
# =====================
# Threshold: 0.02
# Total Money Lost: 210960
# =====================
# Threshold: 0.03
# Total Money Lost: 141320
# =====================
# Threshold: 0.04
# Total Money Lost: 108380
# =====================
# Threshold: 0.05
# Total Money Lost: 89440
# =====================
# Threshold: 0.06
# Total Money Lost: 78680
# =====================
# Threshold: 0.07
# Total Money Lost: 71360
# =====================
# Threshold: 0.08
# Total Money Lost: 65340
# =====================
# Threshold: 0.09
# Total Money Lost: 61600
# =====================
# Threshold: 0.1
# Total Money Lost: 58940
# =====================
# Threshold: 0.11
# Total Money Lost: 57360
# =====================
# Threshold: 0.12
# Total Money Lost: 55600
# =====================
# Threshold: 0.13
# Total Money Lost: 53840
# =====================
# Threshold: 0.14
# Total Money Lost: 53080
# =====================
# Threshold: 0.15
# Total Money Lost: 52540
# =====================
# Threshold: 0.16
# Total Money Lost: 51980
# =====================
# Threshold: 0.17
# Total Money Lost: 51380
# =====================
# Threshold: 0.18
# Total Money Lost: 50720
# =====================
# Threshold: 0.19
# Total Money Lost: 50520
# =====================
# Threshold: 0.2
# Total Money Lost: 50480
# =====================
# Threshold: 0.21
# Total Money Lost: 50080
# =====================
# Threshold: 0.22
# Total Money Lost: 49920
# =====================
# Threshold: 0.23
# Total Money Lost: 49900
# =====================
# Threshold: 0.24
# Total Money Lost: 49360
# =====================
# Threshold: 0.25
# Total Money Lost: 49560
# =====================
# Threshold: 0.26
# Total Money Lost: 49380
# =====================
# Threshold: 0.27
# Total Money Lost: 49540
# =====================
# Threshold: 0.28
# Total Money Lost: 49360
# =====================
# Threshold: 0.29
# Total Money Lost: 49080
# =====================
# Threshold: 0.3
# Total Money Lost: 48720
# =====================
# Threshold: 0.31
# Total Money Lost: 48760
# =====================
# Threshold: 0.32
# Total Money Lost: 48960
# =====================
# Threshold: 0.33
# Total Money Lost: 49120
# =====================
# Threshold: 0.34
# Total Money Lost: 49180
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 48920
# =====================
# Threshold: 0.36
# Total Money Lost: 48840
# =====================
# Threshold: 0.37
# Total Money Lost: 48780
# =====================
# Threshold: 0.38
# Total Money Lost: 48600
# =====================
# Threshold: 0.39
# Total Money Lost: 48640
# =====================
# Threshold: 0.4
# Total Money Lost: 48680
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 48580
# =====================
# Threshold: 0.42
# Total Money Lost: 49100
# =====================
# Threshold: 0.43
# Total Money Lost: 49200
# =====================
# Threshold: 0.44
# Total Money Lost: 49440
# =====================
# Threshold: 0.45
# Total Money Lost: 49700
# =====================
# Threshold: 0.46
# Total Money Lost: 49920
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 50040
# =====================
# Threshold: 0.48
# Total Money Lost: 50280
# =====================
# Threshold: 0.49
# Total Money Lost: 50980
# =====================
# Threshold: 0.5
# Total Money Lost: 51080
# =====================
# Threshold: 0.51
# Total Money Lost: 51260
# =====================
# Threshold: 0.52
# Total Money Lost: 52080
# =====================
# Threshold: 0.53
# Total Money Lost: 52360
# =====================
# Threshold: 0.54
# Total Money Lost: 53160
# =====================
# Threshold: 0.55
# Total Money Lost: 53480
# =====================
# Threshold: 0.56
# Total Money Lost: 53980
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 54120
# =====================
# Threshold: 0.58
# Total Money Lost: 54240
# =====================
# Threshold: 0.59
# Total Money Lost: 54560
# =====================
# Threshold: 0.6
# Total Money Lost: 54920
# =====================
# Threshold: 0.61
# Total Money Lost: 54940
# =====================
# Threshold: 0.62
# Total Money Lost: 55620
# =====================
# Threshold: 0.63
# Total Money Lost: 56420
# =====================
# Threshold: 0.64
# Total Money Lost: 56820
# =====================
# Threshold: 0.65
# Total Money Lost: 57400
# =====================
# Threshold: 0.66
# Total Money Lost: 57880
# =====================
# Threshold: 0.67
# Total Money Lost: 58220
# =====================
# Threshold: 0.68
# Total Money Lost: 58480
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 59520
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 60440
# =====================
# Threshold: 0.71
# Total Money Lost: 61540
# =====================
# Threshold: 0.72
# Total Money Lost: 62440
# =====================
# Threshold: 0.73
# Total Money Lost: 63600
# =====================
# Threshold: 0.74
# Total Money Lost: 64460
# =====================
# Threshold: 0.75
# Total Money Lost: 65720
# =====================
# Threshold: 0.76
# Total Money Lost: 66680
# =====================
# Threshold: 0.77
# Total Money Lost: 67900
# =====================
# Threshold: 0.78
# Total Money Lost: 69500
# =====================
# Threshold: 0.79
# Total Money Lost: 70700
# =====================
# Threshold: 0.8
# Total Money Lost: 72320
# =====================
# Threshold: 0.81
# Total Money Lost: 73580
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 75320
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 76960
# =====================
# Threshold: 0.84
# Total Money Lost: 79080
# =====================
# Threshold: 0.85
# Total Money Lost: 81220
# =====================
# Threshold: 0.86
# Total Money Lost: 84640
# =====================
# Threshold: 0.87
# Total Money Lost: 86900
# =====================
# Threshold: 0.88
# Total Money Lost: 91760
# =====================
# Threshold: 0.89
# Total Money Lost: 95180
# =====================
# Threshold: 0.9
# Total Money Lost: 99380
# =====================
# Threshold: 0.91
# Total Money Lost: 105360
# =====================
# Threshold: 0.92
# Total Money Lost: 111700
# =====================
# Threshold: 0.93
# Total Money Lost: 118380
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 127720
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 141140
# =====================
# Threshold: 0.96
# Total Money Lost: 160180
# =====================
# Threshold: 0.97
# Total Money Lost: 186600
# =====================
# Threshold: 0.98
# Total Money Lost: 237980
# =====================
# Threshold: 0.99
# Total Money Lost: 350640
# =====================
# Threshold: 1.0
# Total Money Lost: 1282300
# =====================
# ====================
# Split 4
# Epoch 1/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0846 - accuracy: 0.9753 - val_loss: 0.0683 - val_accuracy: 0.9798
# Epoch 2/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0792 - accuracy: 0.9765 - val_loss: 0.0741 - val_accuracy: 0.9780
# Epoch 3/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0777 - accuracy: 0.9772 - val_loss: 0.0711 - val_accuracy: 0.9784
# Epoch 4/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0768 - accuracy: 0.9775 - val_loss: 0.0752 - val_accuracy: 0.9771
# Epoch 5/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0744 - accuracy: 0.9785 - val_loss: 0.0778 - val_accuracy: 0.9755
# Epoch 6/1000
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.0733 - accuracy: 0.9784 - val_loss: 0.0788 - val_accuracy: 0.9759
# 1000/1000 [==============================] - 1s 581us/step
# Threshold: 0.0
# Total Money Lost: 766400
# =====================
# Threshold: 0.01
# Total Money Lost: 264300
# =====================
# Threshold: 0.02
# Total Money Lost: 151260
# =====================
# Threshold: 0.03
# Total Money Lost: 106220
# =====================
# Threshold: 0.04
# Total Money Lost: 85140
# =====================
# Threshold: 0.05
# Total Money Lost: 73640
# =====================
# Threshold: 0.06
# Total Money Lost: 68500
# =====================
# Threshold: 0.07
# Total Money Lost: 63920
# =====================
# Threshold: 0.08
# Total Money Lost: 60580
# =====================
# Threshold: 0.09
# Total Money Lost: 58100
# =====================
# Threshold: 0.1
# Total Money Lost: 56440
# =====================
# Threshold: 0.11
# Total Money Lost: 54780
# =====================
# Threshold: 0.12
# Total Money Lost: 53640
# =====================
# Threshold: 0.13
# Total Money Lost: 52480
# =====================
# Threshold: 0.14
# Total Money Lost: 51160
# =====================
# Threshold: 0.15
# Total Money Lost: 50220
# =====================
# Threshold: 0.16
# Total Money Lost: 49560
# =====================
# Threshold: 0.17
# Total Money Lost: 49140
# =====================
# Threshold: 0.18
# Total Money Lost: 48640
# =====================
# Threshold: 0.19
# Total Money Lost: 48500
# =====================
# Threshold: 0.2
# Total Money Lost: 48260
# =====================
# Threshold: 0.21
# Total Money Lost: 47880
# =====================
# Threshold: 0.22
# Total Money Lost: 47380
# =====================
# Threshold: 0.23
# Total Money Lost: 46620
# =====================
# Threshold: 0.24
# Total Money Lost: 46520
# =====================
# Threshold: 0.25
# Total Money Lost: 46420
# =====================
# Threshold: 0.26
# Total Money Lost: 46060
# =====================
# Threshold: 0.27
# Total Money Lost: 45840
# =====================
# Threshold: 0.28
# Total Money Lost: 45500
# =====================
# Threshold: 0.29
# Total Money Lost: 45780
# =====================
# Threshold: 0.3
# Total Money Lost: 45720
# =====================
# Threshold: 0.31
# Total Money Lost: 45440
# =====================
# Threshold: 0.32
# Total Money Lost: 45920
# =====================
# Threshold: 0.33
# Total Money Lost: 46080
# =====================
# Threshold: 0.34
# Total Money Lost: 46860
# =====================
# Threshold: 0.35000000000000003
# Total Money Lost: 46960
# =====================
# Threshold: 0.36
# Total Money Lost: 47120
# =====================
# Threshold: 0.37
# Total Money Lost: 47160
# =====================
# Threshold: 0.38
# Total Money Lost: 46980
# =====================
# Threshold: 0.39
# Total Money Lost: 46900
# =====================
# Threshold: 0.4
# Total Money Lost: 47120
# =====================
# Threshold: 0.41000000000000003
# Total Money Lost: 47440
# =====================
# Threshold: 0.42
# Total Money Lost: 48000
# =====================
# Threshold: 0.43
# Total Money Lost: 48340
# =====================
# Threshold: 0.44
# Total Money Lost: 48820
# =====================
# Threshold: 0.45
# Total Money Lost: 48880
# =====================
# Threshold: 0.46
# Total Money Lost: 49660
# =====================
# Threshold: 0.47000000000000003
# Total Money Lost: 50240
# =====================
# Threshold: 0.48
# Total Money Lost: 50340
# =====================
# Threshold: 0.49
# Total Money Lost: 50840
# =====================
# Threshold: 0.5
# Total Money Lost: 50980
# =====================
# Threshold: 0.51
# Total Money Lost: 50820
# =====================
# Threshold: 0.52
# Total Money Lost: 50800
# =====================
# Threshold: 0.53
# Total Money Lost: 51020
# =====================
# Threshold: 0.54
# Total Money Lost: 51180
# =====================
# Threshold: 0.55
# Total Money Lost: 51360
# =====================
# Threshold: 0.56
# Total Money Lost: 51520
# =====================
# Threshold: 0.5700000000000001
# Total Money Lost: 51880
# =====================
# Threshold: 0.58
# Total Money Lost: 52500
# =====================
# Threshold: 0.59
# Total Money Lost: 52960
# =====================
# Threshold: 0.6
# Total Money Lost: 53280
# =====================
# Threshold: 0.61
# Total Money Lost: 54180
# =====================
# Threshold: 0.62
# Total Money Lost: 55060
# =====================
# Threshold: 0.63
# Total Money Lost: 55420
# =====================
# Threshold: 0.64
# Total Money Lost: 55540
# =====================
# Threshold: 0.65
# Total Money Lost: 56280
# =====================
# Threshold: 0.66
# Total Money Lost: 56740
# =====================
# Threshold: 0.67
# Total Money Lost: 57820
# =====================
# Threshold: 0.68
# Total Money Lost: 58120
# =====================
# Threshold: 0.6900000000000001
# Total Money Lost: 59200
# =====================
# Threshold: 0.7000000000000001
# Total Money Lost: 60520
# =====================
# Threshold: 0.71
# Total Money Lost: 61240
# =====================
# Threshold: 0.72
# Total Money Lost: 62400
# =====================
# Threshold: 0.73
# Total Money Lost: 63940
# =====================
# Threshold: 0.74
# Total Money Lost: 64700
# =====================
# Threshold: 0.75
# Total Money Lost: 65640
# =====================
# Threshold: 0.76
# Total Money Lost: 66820
# =====================
# Threshold: 0.77
# Total Money Lost: 67540
# =====================
# Threshold: 0.78
# Total Money Lost: 69080
# =====================
# Threshold: 0.79
# Total Money Lost: 70900
# =====================
# Threshold: 0.8
# Total Money Lost: 72500
# =====================
# Threshold: 0.81
# Total Money Lost: 74160
# =====================
# Threshold: 0.8200000000000001
# Total Money Lost: 76340
# =====================
# Threshold: 0.8300000000000001
# Total Money Lost: 78820
# =====================
# Threshold: 0.84
# Total Money Lost: 80420
# =====================
# Threshold: 0.85
# Total Money Lost: 82600
# =====================
# Threshold: 0.86
# Total Money Lost: 86520
# =====================
# Threshold: 0.87
# Total Money Lost: 89700
# =====================
# Threshold: 0.88
# Total Money Lost: 92500
# =====================
# Threshold: 0.89
# Total Money Lost: 96140
# =====================
# Threshold: 0.9
# Total Money Lost: 99760
# =====================
# Threshold: 0.91
# Total Money Lost: 105780
# =====================
# Threshold: 0.92
# Total Money Lost: 112460
# =====================
# Threshold: 0.93
# Total Money Lost: 118100
# =====================
# Threshold: 0.9400000000000001
# Total Money Lost: 129440
# =====================
# Threshold: 0.9500000000000001
# Total Money Lost: 143360
# =====================
# Threshold: 0.96
# Total Money Lost: 163860
# =====================
# Threshold: 0.97
# Total Money Lost: 198100
# =====================
# Threshold: 0.98
# Total Money Lost: 261220
# =====================
# Threshold: 0.99
# Total Money Lost: 388740
# =====================
# Threshold: 1.0
# Total Money Lost: 1282900
# =====================

# %%
print(sum(nnCost))
# Out:
# 290860
