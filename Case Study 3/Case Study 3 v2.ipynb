# %%
import os
import email
import re
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.cluster import KMeans
import string  
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import unicodedata
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
nltk.download('stopwords')
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_predict
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\austi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
folder_name = 'SpamAssassinMessages'

# Function to search for the folder recursively
def find_folder(start_dir, folder_name):
    for root, dirs, files in os.walk(start_dir):
        if folder_name in dirs:
            folder_path = os.path.join(root, folder_name)
            print(f"The path of '{folder_name}' is: {folder_path}")
        
# Start the search from the root directory (you can specify a different directory)
start_directory = '/'

find_folder(start_directory, folder_name)
# Out:
# The path of 'SpamAssassinMessages' is: /Users\austi\Downloads\SpamAssassinMessages

# %%
def extract_text_from_message(message):
    
    text = ""
    if message.is_multipart():
        for part in message.walk():
            content_type = part.get_content_type()
            content_disposition = str(part.get('Content-Disposition'))

            if 'attachment' not in content_disposition:
                payload = part.get_payload(decode = True)
                if payload:
                    if content_type == 'text/html':
                        soup = BeautifulSoup(payload, 'html.parser')
                        text += soup.get_text()
                    else:
                        text += payload.decode('utf-8', errors = 'ignore')
    else:
        payload = message.get_payload(decode = True)
        if payload:
            if message.get_content_type() == 'text/html':
                soup = BeautifulSoup(payload, 'html.parser')
                text = soup.get_text()
            else:
                text = payload.decode('utf-8', errors = 'ignore')

    text = text.lower()
    text = ''.join([char for char in text if char not in string.punctuation])
    
    stop_words = set(stopwords.words('english'))  
    words = text.split()  
    filtered_words = [word for word in words if word not in stop_words]  
    
    text = ' '.join(filtered_words)  
    
    return text

# %%
def extract_sender(message):
    sender = 'None'  

    if 'From' in message:
        sender = message['From']

    return sender

# %%
def extract_message_type(message):
    if message.is_multipart():
        return 'multipart'
    else:
        return message.get_content_type()

# %%
directory_path = r'/Users/austi/Downloads/SpamAssassinMessages/'

file_name = []
label = []
msgs = []
senders = [] 
message_types = []

for root, dirs, files in os.walk(directory_path):
    for file in files:
        file_path = os.path.join(root, file)
        
        if 'spam' in root:
            label.append(1)
        else:
            label.append(0)
        
        with open(file_path, 'r', encoding = 'latin-1') as file_handle:
            message = email.message_from_file(file_handle)
            text = extract_text_from_message(message)
            
            text = ''.join([c for c in text if not unicodedata.category(c).startswith('C')])
            
            msgs.append(text)
            
            sender = extract_sender(message)
            senders.append(sender)
            
            message_type = extract_message_type(message)
            message_types.append(message_type)
            
        file_name.append(file_path)

data = {'File Name': file_name, 
        'Label': label,
        'Message': msgs,
        'Sender': senders,
        'Message Type': message_types}

df = pd.DataFrame(data)

# this is where lots of the weird messages are
df.tail(50)
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#                                               File Name  Label  \
# 9303  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9304  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9305  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9306  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9307  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9308  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9309  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9310  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9311  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9312  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9313  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9314  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9315  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9316  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9317  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9318  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9319  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9320  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9321  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9322  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9323  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9324  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9325  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9326  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9327  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9328  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9329  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9330  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9331  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9332  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9333  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9334  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9335  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9336  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9337  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9338  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9339  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9340  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9341  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9342  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9343  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9344  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9345  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9346  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9347  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9348  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9349  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9350  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9351  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
# 9352  /Users/austi/Downloads/SpamAssassinMessages/sp...      1
#
#                                                 Message  \
# 9303  lowest rates available term life insurance tak...
# 9304  ricardo olá trabalho divulgando empresas séria...
# 9305  fill short application unbelievable 41 mortgag...
# 9306  offer best bulk email prices internet bulk ema...
# 9307  giftcd offer newsletter confirmation august 8t...
# 9308  18 21 yr old chicks horny nasty amateurs takin...
# 9309  norton systemworks 2002software suite professi...
# 9310  dear sir fetch name internet month group set o...
# 9311  dental plans 695 per month dental plans 695 pe...
# 9312  result feedback form submitted reenspringhappy...
# 9313  free media sofware link enjoy jim httpwwwfreeo...
# 9314  click see promotion mail monitors httpwwwbluec...
# 9315  selling travel todays economy good morning sin...
# 9316  need help 14 year old fortune 500 company grow...
# 9317  big big main page huge big titties bigbigscom ...
# 9318  mailv06cgif receiving mailing member sendgreat...
# 9319  web pages load 300 faster named online softwar...
# 9320  need help 14 year old fortune 500 company grow...
# 9321  opportunity knocking mortgage rates rising nat...
# 9322  untitled document dont victim tracks missing c...
# 9323  mother natures natural marital aid men women r...
# 9324  automated home based business online sales boo...
# 9325  dear guests explore turkey astartetours hotel ...
# 9326  new page 1 free service mortgage rates never l...
# 9327  degree may closer think remove obstacles cause...
# 9328  want thank past business wish happy thanksgivi...
# 9329  protect purchase extended warranty car existin...
# 9330  could please kind renew topsitesus directory l...
# 9331  friend recently introduced amazing shopping ex...
# 9332  mailv05agif receiving mailing member sendgreat...
# 9333  degree may closer think remove obstacles cause...
# 9334  computer reads aloud collection includes compl...
# 9335  httpwwwefrsecuritiescomadviseasp companys inve...
# 9336  see teen farm girl horse see free think seen p...
# 9337  webmaster cadastrese agora mesmo divulgue seu ...
# 9338  discovered jmasonorg yahoo favorite directory ...
# 9339  hello get emails every day offering show make ...
# 9340  want make 1000 per week motivated qualified in...
# 9341  message sent unsolicited received email member...
# 9342  buy generic sildenafil citrate online active i...
# 9343  httpwwwwebheadsweeklycombabesshavedkarstenbabe...
# 9344  lose weight building lean muscle mass reversin...
# 9345  dear jmnetnoteinccom miss envc 280 prct 300 hu...
# 9346  hear interest rates lowered dont delay get fre...
# 9347  want boss train selfpaced home study thousands...
# 9348  preferred nonsmoker doctor ordered case study ...
# 9349  dear subscriber could show way get 10000 visit...
# 9350  midsummer customer appreciation sale express a...
# 9351  attnsirmadan strictly confidential pleased int...
# 9352  mv 00001317e78fa8ee2f54cd4890fdc09ba8176 00001...
#
#                                                  Sender Message Type
# 9303           firstever001@now3.takemetothesavings.com   text/plain
# 9304                 "_Ricardo_" <topseg321@bol.com.br>    text/html
# 9305         "Stephanie Orville" <blain8488@runbox.com>    text/html
# 9306                    salesandleads2628@Flashmail.com   text/plain
# 9307                  "GiftCD Alert" <alert@giftcd.com>   text/plain
# 9308                     "Alex" <alexa122_bwer@msg.com>    text/html
# 9309                                 zarco9@hotmail.com    text/html
# 9310  "Ms.Huang (Sales Manager)" <motorcycle@qinghec...    multipart
# 9311              "1st Dental Plans" <eml7@hotmail.com>    text/html
# 9312                         reenspring@happyman.com ()   text/plain
# 9313  idxxHQH FREE Jimmy <wvJimmyfreel1180xoxo@c1net...   text/plain
# 9314                                   news@bluecom.com    multipart
# 9315                  "Bob Maier" <info7@mailpound.com>    text/html
# 9316                                     jtr4@zonnet.nl   text/plain
# 9317  "BIG TITS" <bignaturaltittiesthatarefun@froma2...    text/html
# 9318        Lowest LD <greatoffers@sendgreatoffers.com>    text/html
# 9319         "Free Software" <rjiohm4027@Flashmail.com>    text/html
# 9320                                    scott@hetnet.nl   text/plain
# 9321                           alvalinen33@netscape.net   text/plain
# 9322                          vcyonjqktt@compuserve.com    text/html
# 9323                "Rachel" <qy1cykr1g86312@yahoo.com>    text/html
# 9324                              bc2larsen@hotmail.com    text/html
# 9325               "Astarte Turizm" <astarte@veezy.com>   text/plain
# 9326            "Kirk Umfleet" <Sidney22@webmail.co.za>    text/html
# 9327                 Paula Gaiger <Rocheldy@webinfo.fi>   text/plain
# 9328       "Cristina" <cristina@collectorsinternet.com>    multipart
# 9329                      cristopherwotton@netscape.net   text/plain
# 9330             "Paul Thomas" <postmaster@topsitez.us>    multipart
# 9331                       "Pat" <valentart@runbox.com>   text/plain
# 9332  Lowest Long Distance <ldistancesgo@SendGreatOf...    text/html
# 9333              Shanika Piyasena <Jacquiro@tjohoo.se>   text/plain
# 9334         Bradley Brunoni <txoaplc@go-fishing.co.uk>    text/html
# 9335                         profile@e-frsecurities.com    multipart
# 9336                        moviedbjwuede@mandic.com.br   text/plain
# 9337     "PARQUIEJO DII TROYA" <webmaster@ibest.com.br>   text/plain
# 9338        Donna Martos <donnamartos@link-builder.com>   text/plain
# 9339                             Tim3h85kg9@bigfoot.com   text/plain
# 9340                                     mik323@usa.net   text/plain
# 9341     Omaha Steaks <steakssgo37@SendGreatOffers.com>    text/html
# 9342                           "Jamie" <Jhon67@aol.com>    text/html
# 9343    "Kena Wedlock" <KenaWedlock@webheadsweekly.com>   text/plain
# 9344          Lose Weight <LoseWeight@DIRECT4OPTIN.COM>    text/html
# 9345     "4544032@mcimail.com" <alh4544032@mcimail.com>    text/html
# 9346                   johnson11@aa64.toplinequotes.com   text/plain
# 9347  Professional_Career_Development_Institute@Frug...    text/html
# 9348                          "IQ - TBA" <tba@insiq.us>    multipart
# 9349                               Mike <raye@yahoo.lv>   text/plain
# 9350                   "Mr. Clean" <cweqx@dialix.oz.au>   text/plain
# 9351  "wilsonkamela400@netscape.net" <wilsonkamela50...   text/plain
# 9352                                               None   text/plain

# %%
message_type_counts = df['Message Type'].value_counts()

print(message_type_counts)
# Out:
# Message Type
# text/plain                     7413
# text/html                      1193
# multipart                       743
# multipart/alternative             3
# text/plain charset=us-ascii       1
# Name: count, dtype: int64

# %%
stop_words = list(ENGLISH_STOP_WORDS)

X_train, X_test, y_train, y_test = train_test_split(df['Message'], 
                                                    df['Label'],
                                                    test_size = 0.2,
                                                    random_state = 42)

alpha_values = [0.001, 0.01, 0.1, 0.5, 1.0, 1.5, 2.0]

for alpha in alpha_values:
    vectorizer = TfidfVectorizer(stop_words = stop_words)
    X_train_transformed = vectorizer.fit_transform(X_train)
    X_test_transformed = vectorizer.transform(X_test)
    
    nb_classifier = MultinomialNB(alpha = alpha)
    nb_classifier.fit(X_train_transformed, y_train)
    
    y_pred = nb_classifier.predict(X_test_transformed)
    
    report = classification_report(y_test, y_pred)
    print(f'Alpha = {alpha}\n{report}\n')
    print('--------------------------------------------------------')
# Out:
# Alpha = 0.001
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1391
#            1       0.99      0.97      0.98       480
#
#     accuracy                           0.99      1871
#    macro avg       0.99      0.98      0.99      1871
# weighted avg       0.99      0.99      0.99      1871
#
#
# --------------------------------------------------------
# Alpha = 0.01
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1391
#            1       1.00      0.97      0.98       480
#
#     accuracy                           0.99      1871
#    macro avg       0.99      0.99      0.99      1871
# weighted avg       0.99      0.99      0.99      1871
#
#
# --------------------------------------------------------
# Alpha = 0.1
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1391
#            1       1.00      0.96      0.98       480
#
#     accuracy                           0.99      1871
#    macro avg       0.99      0.98      0.99      1871
# weighted avg       0.99      0.99      0.99      1871
#
#
# --------------------------------------------------------
# Alpha = 0.5
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1391
#            1       1.00      0.87      0.93       480
#
#     accuracy                           0.97      1871
#    macro avg       0.98      0.94      0.96      1871
# weighted avg       0.97      0.97      0.97      1871
#
#
# --------------------------------------------------------
# Alpha = 1.0
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      1391
#            1       1.00      0.75      0.85       480
#
#     accuracy                           0.93      1871
#    macro avg       0.96      0.87      0.91      1871
# weighted avg       0.94      0.93      0.93      1871
#
#
# --------------------------------------------------------
# Alpha = 1.5
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      1391
#            1       1.00      0.68      0.81       480
#
#     accuracy                           0.92      1871
#    macro avg       0.95      0.84      0.88      1871
# weighted avg       0.93      0.92      0.91      1871
#
#
# --------------------------------------------------------
# Alpha = 2.0
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93      1391
#            1       1.00      0.60      0.75       480
#
#     accuracy                           0.90      1871
#    macro avg       0.94      0.80      0.84      1871
# weighted avg       0.91      0.90      0.89      1871
#
#
# --------------------------------------------------------

# %%
stop_words = list(ENGLISH_STOP_WORDS)


df['Label'] = df['Label'].astype(int) 
X = df['Message']
y = df['Label']

alpha_values = [0.001, 0.01, 0.1, 0.5, 1.0, 1.5, 2.0]

for alpha in alpha_values:
    vectorizer = TfidfVectorizer(stop_words = stop_words)
    X_transformed = vectorizer.fit_transform(X)
    
    nb_classifier = MultinomialNB(alpha = alpha)
    
    scores = cross_val_score(nb_classifier,
                             X_transformed,
                             y,
                             cv = 5,
                             scoring = 'f1_macro')
    
    print(f'Alpha = {alpha}')
    print(f'Cross-Validation Scores: {scores}')
    print(f'Mean F1 Score: {np.mean(scores)}\n')
    print('--------------------------------------------------------')
# Out:
# Alpha = 0.001
# Cross-Validation Scores: [0.99300393 0.997894   0.96745087 0.97716731 0.89931107]
# Mean F1 Score: 0.9669654377891204
#
# --------------------------------------------------------
# Alpha = 0.01
# Cross-Validation Scores: [0.99020551 0.997894   0.97413197 0.98299629 0.88240493]
# Mean F1 Score: 0.9655265399857855
#
# --------------------------------------------------------
# Alpha = 0.1
# Cross-Validation Scores: [0.99086146 0.99365581 0.9711737  0.97500889 0.89194338]
# Mean F1 Score: 0.9645286481743668
#
# --------------------------------------------------------
# Alpha = 0.5
# Cross-Validation Scores: [0.96819768 0.96445229 0.91042561 0.92449935 0.91974052]
# Mean F1 Score: 0.9374630906732856
#
# --------------------------------------------------------
# Alpha = 1.0
# Cross-Validation Scores: [0.91461188 0.90704984 0.84369031 0.84723684 0.89544849]
# Mean F1 Score: 0.8816074704411208
#
# --------------------------------------------------------
# Alpha = 1.5
# Cross-Validation Scores: [0.85988131 0.85706443 0.79577608 0.7942405  0.87100931]
# Mean F1 Score: 0.835594327494527
#
# --------------------------------------------------------
# Alpha = 2.0
# Cross-Validation Scores: [0.82892401 0.82187045 0.76242396 0.76186268 0.84075214]
# Mean F1 Score: 0.8031666464036838
#
# --------------------------------------------------------

# %%
stop_words = list(ENGLISH_STOP_WORDS)

df['Label'] = df['Label'].astype(int) 
X = df['Message']
y = df['Label']

alpha_values = [0.001, 0.01, 0.1, 0.5, 1.0, 1.5, 2.0]

for alpha in alpha_values:
    vectorizer = TfidfVectorizer(stop_words = stop_words)
    X_transformed = vectorizer.fit_transform(X)
    
    nb_classifier = MultinomialNB(alpha = alpha)
    
    scores = cross_val_score(nb_classifier, 
                             X_transformed,
                             y,
                             cv = 5,
                             scoring = 'f1_macro')
    
    y_pred = cross_val_predict(nb_classifier, 
                               X_transformed,
                               y,
                               cv = 5)
    
    accuracy = accuracy_score(y, y_pred)
    precision = precision_score(y, y_pred)
    recall = recall_score(y, y_pred)
    
    print(f'Alpha = {alpha}')
    print(f'Cross-Validation F1 Score: {np.mean(scores)}')
    print(f'Cross-Validation Accuracy: {accuracy}')
    print(f'Cross-Validation Precision: {precision}')
    print(f'Cross-Validation Recall: {recall}\n')
    print('--------------------------------------------------------')
# Out:
# Alpha = 0.001
# Cross-Validation F1 Score: 0.9669654377891204
# Cross-Validation Accuracy: 0.9739121137602909
# Cross-Validation Precision: 0.9414174518639902
# Cross-Validation Recall: 0.9578991246352647
#
# --------------------------------------------------------
# Alpha = 0.01
# Cross-Validation F1 Score: 0.9655265399857855
# Cross-Validation Accuracy: 0.9719875975622795
# Cross-Validation Precision: 0.9251890171110226
# Cross-Validation Recall: 0.9691538140892039
#
# --------------------------------------------------------
# Alpha = 0.1
# Cross-Validation F1 Score: 0.9645286481743668
# Cross-Validation Accuracy: 0.9717737624291671
# Cross-Validation Precision: 0.9355365157078743
# Cross-Validation Recall: 0.9558149228845352
#
# --------------------------------------------------------
# Alpha = 0.5
# Cross-Validation F1 Score: 0.9374630906732856
# Cross-Validation Accuracy: 0.9548807869132898
# Cross-Validation Precision: 0.9800874210781932
# Cross-Validation Recall: 0.8411838265944144
#
# --------------------------------------------------------
# Alpha = 1.0
# Cross-Validation F1 Score: 0.8816074704411208
# Cross-Validation Accuracy: 0.9200256602159735
# Cross-Validation Precision: 0.9928358208955224
# Cross-Validation Recall: 0.6932055022926219
#
# --------------------------------------------------------
# Alpha = 1.5
# Cross-Validation F1 Score: 0.835594327494527
# Cross-Validation Accuracy: 0.8939377739762643
# Cross-Validation Precision: 0.994378074490513
# Cross-Validation Recall: 0.5898290954564401
#
# --------------------------------------------------------
# Alpha = 2.0
# Cross-Validation F1 Score: 0.8031666464036838
# Cross-Validation Accuracy: 0.8771517160269432
# Cross-Validation Precision: 1.0
# Cross-Validation Recall: 0.5210504376823677
#
# --------------------------------------------------------
